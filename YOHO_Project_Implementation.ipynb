# %% [markdown]
# # Initial Imports

# %%
from zipfile import ZipFile
import glob
import csv
import random
from subprocess import Popen, PIPE
from keras import regularizers
from os.path import dirname
import os
import soundfile as sf
# !sudo apt-get install sox
import math
import numpy as np
import librosa
import shutil
import pickle
import re
import tensorflow as tf
# !git clone https://github.com/DemisEom/SpecAugment.git
# !pip install /content/SpecAugment/ --quiet
# !pip install tensorflow-addons --quiet
# !pip install sed_eval --quiet
import keras
from SpecAugment import spec_augment_tensorflow
import sed_eval
import dcase_util
from keras import regularizers
from keras.regularizers import l2

# %%
# !pip install gdown
import gdown

output1 = "/content/new-dataset/test_data1.zip"
gdown.download(id='17PvyXLEkpIgBLxRkuTIk25MGL3uM3kS1', output=output1, quiet=False)

output2= "/content/new-dataset/test_data2.zip"
gdown.download(id='14abMPBH3EVmcU-3jPD4jWEpa4pQ38OY9', output=output2, quiet=False)

output3 = "/content/new-dataset/test_data3.zip"
gdown.download(id='1TU4CoJuFy40-zJopo3R4U-YgZFKFrtxB', output=output3, quiet=False)

output4 = "/content/new-dataset/test_data4.zip"
gdown.download(id='1E5595RX2NwpuckXvl2o1V_dm9Ja58arF', output=output4, quiet=False)

output5 = "/content/new-dataset/test_data5.zip"
gdown.download(id='16VJhkCV2-ILcHxiF8a2ygEiHxXyF9RtM', output=output5, quiet=False)

output6 = "/content/new-dataset/test_data6.zip"
gdown.download(id='1kZyXyZVTHnSTg-gdrlf91V5ioYMr50Mp', output=output6, quiet=False)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.9/dist-packages (4.6.6)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.9/dist-packages (from gdown) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from gdown) (3.10.7)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from gdown) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->gdown) (2.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (2.0.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From: https://drive.google.com/uc?id=17PvyXLEkpIgBLxRkuTIk25MGL3uM3kS1
# To: /content/new-dataset/test_data1.zip
# 100%|██████████| 1.38G/1.38G [00:04<00:00, 300MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=14abMPBH3EVmcU-3jPD4jWEpa4pQ38OY9
# To: /content/new-dataset/test_data2.zip
# 100%|██████████| 1.38G/1.38G [00:09<00:00, 149MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1TU4CoJuFy40-zJopo3R4U-YgZFKFrtxB
# To: /content/new-dataset/test_data3.zip
# 100%|██████████| 1.34G/1.34G [00:08<00:00, 164MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1E5595RX2NwpuckXvl2o1V_dm9Ja58arF
# To: /content/new-dataset/test_data4.zip
# 100%|██████████| 1.32G/1.32G [00:08<00:00, 158MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=16VJhkCV2-ILcHxiF8a2ygEiHxXyF9RtM
# To: /content/new-dataset/test_data5.zip
# 100%|██████████| 1.29G/1.29G [00:08<00:00, 144MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1kZyXyZVTHnSTg-gdrlf91V5ioYMr50Mp
# To: /content/new-dataset/test_data6.zip
# 100%|██████████| 792M/792M [00:05<00:00, 142MB/s]
# '/content/new-dataset/test_data6.zip'

# %% [markdown]
# # Download Development Dataset (Train/Val)

# %%
def download_train_data():
  download_path = "/content/datasetZipped/"
  # !mkdir $download_path
  # get first both audio set zips
  # !wget https://zenodo.org/record/814831/files/TUT-sound-events-2017-development.audio.1.zip?download=1 -O {download_path}TUT-sound-events-2017-development.audio.1.zip
  # !wget https://zenodo.org/record/814831/files/TUT-sound-events-2017-development.audio.2.zip?download=1 -O {download_path}TUT-sound-events-2017-development.audio.2.zip
  # download labels and related metadata
  # !wget https://zenodo.org/record/814831/files/TUT-sound-events-2017-development.doc.zip?download=1 -O {download_path}TUT-sound-events-2017-development.doc.zip
  # !wget https://zenodo.org/record/814831/files/TUT-sound-events-2017-development.meta.zip?download=1 -O {download_path}TUT-sound-events-2017-development.meta.zip

# %%
# Download the actual data
download_train_data()
# Out:
# --2023-03-31 22:56:21--  https://zenodo.org/record/814831/files/TUT-sound-events-2017-development.audio.1.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1062653169 (1013M) [application/octet-stream]
# Saving to: ‘/content/datasetZipped/TUT-sound-events-2017-development.audio.1.zip’
#
# /content/datasetZip 100%[===================>]   1013M  29.0MB/s    in 36s
#
# 2023-03-31 22:56:59 (28.1 MB/s) - ‘/content/datasetZipped/TUT-sound-events-2017-development.audio.1.zip’ saved [1062653169/1062653169]
#
# --2023-03-31 22:56:59--  https://zenodo.org/record/814831/files/TUT-sound-events-2017-development.audio.2.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 213232458 (203M) [application/octet-stream]
# Saving to: ‘/content/datasetZipped/TUT-sound-events-2017-development.audio.2.zip’
#
# /content/datasetZip 100%[===================>] 203.35M  28.8MB/s    in 7.8s
#
# 2023-03-31 22:57:08 (26.1 MB/s) - ‘/content/datasetZipped/TUT-sound-events-2017-development.audio.2.zip’ saved [213232458/213232458]
#
# --2023-03-31 22:57:08--  https://zenodo.org/record/814831/files/TUT-sound-events-2017-development.doc.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56150 (55K) [application/octet-stream]
# Saving to: ‘/content/datasetZipped/TUT-sound-events-2017-development.doc.zip’
#
# /content/datasetZip 100%[===================>]  54.83K  --.-KB/s    in 0.1s
#
# 2023-03-31 22:57:09 (547 KB/s) - ‘/content/datasetZipped/TUT-sound-events-2017-development.doc.zip’ saved [56150/56150]
#
# --2023-03-31 22:57:09--  https://zenodo.org/record/814831/files/TUT-sound-events-2017-development.meta.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 140684 (137K) [application/octet-stream]
# Saving to: ‘/content/datasetZipped/TUT-sound-events-2017-development.meta.zip’
#
# /content/datasetZip 100%[===================>] 137.39K   456KB/s    in 0.3s
#
# 2023-03-31 22:57:10 (456 KB/s) - ‘/content/datasetZipped/TUT-sound-events-2017-development.meta.zip’ saved [140684/140684]

# %% [markdown]
# # Download Test Dataset

# %%
def download_test_data():
  download_path = "/content/EvaluationZipped/"
  # !mkdir $download_path
  # get the audio set zip
  # !wget https://zenodo.org/record/1040179/files/TUT-sound-events-2017-evaluation.audio.zip?download=1 -O {download_path}TUT-sound-events-2017-evaluation.audio.zip  
  # download labels and related metadata
  # !wget https://zenodo.org/record/1040179/files/TUT-sound-events-2017-evaluation.doc.zip?download=1 -O {download_path}TUT-sound-events-2017-evaluation.doc.zip
  # !wget https://zenodo.org/record/1040179/files/TUT-sound-events-2017-evaluation.meta.zip?download=1 -O {download_path}TUT-sound-events-2017-evaluation.meta.zip

# %%
download_test_data()
# Out:
# --2023-04-26 05:16:29--  https://zenodo.org/record/1040179/files/TUT-sound-events-2017-evaluation.audio.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 388173790 (370M) [application/octet-stream]
# Saving to: ‘/content/EvaluationZipped/TUT-sound-events-2017-evaluation.audio.zip’
#
# /content/Evaluation 100%[===================>] 370.19M  3.72MB/s    in 2m 40s
#
# 2023-04-26 05:19:11 (2.31 MB/s) - ‘/content/EvaluationZipped/TUT-sound-events-2017-evaluation.audio.zip’ saved [388173790/388173790]
#
# --2023-04-26 05:19:12--  https://zenodo.org/record/1040179/files/TUT-sound-events-2017-evaluation.doc.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55462 (54K) [application/octet-stream]
# Saving to: ‘/content/EvaluationZipped/TUT-sound-events-2017-evaluation.doc.zip’
#
# /content/Evaluation 100%[===================>]  54.16K   339KB/s    in 0.2s
#
# 2023-04-26 05:19:14 (339 KB/s) - ‘/content/EvaluationZipped/TUT-sound-events-2017-evaluation.doc.zip’ saved [55462/55462]
#
# --2023-04-26 05:19:14--  https://zenodo.org/record/1040179/files/TUT-sound-events-2017-evaluation.meta.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14147 (14K) [application/octet-stream]
# Saving to: ‘/content/EvaluationZipped/TUT-sound-events-2017-evaluation.meta.zip’
#
# /content/Evaluation 100%[===================>]  13.82K  --.-KB/s    in 0s
#
# 2023-04-26 05:19:15 (312 MB/s) - ‘/content/EvaluationZipped/TUT-sound-events-2017-evaluation.meta.zip’ saved [14147/14147]

# %% [markdown]
# #Unzip all The data

# %%
def unzip_data(download_path, extract_path):

  # create glob
  final_glob = glob.glob(f"{download_path}*.zip")

  for zip_name in final_glob:
    with ZipFile(zip_name, 'r') as zip:
      zip.extractall(extract_path)

# %%
download_development_path = '/content/datasetZipped/'
extract_development_path = '/content/development'
download_test_path = '/content/new-dataset/'
extract_test_path = '/content/extracted-data'


# unzip_data(download_development_path, extract_development_path)
unzip_data(download_test_path, extract_test_path)

# %% [markdown]
# # Extract Annotations

# %%
def convert_annotations_to_events(filename): #read_annotations
    events = []
    with open(filename, 'r') as csvfile:
        spamreader = csv.reader(csvfile, delimiter='\t', quotechar='|')
        for row in spamreader:
            row.append(row[0])
            row.pop(0)
            row[1] = str((float(row[1])/1000))
            row[0] = str((float(row[0])/1000))
            events.append(row)
    return events

# %%
events = convert_annotations_to_events("/content/extracted-data/outputs/0.txt")
print(events)
# Out:
# [['0.0', '8.027', 'footsteps'], ['8.027', '10.922', 'rainforest'], ['10.922', '16.762', 'car'], ['16.762', '25.854', 'footsteps'], ['25.854', '34.946', 'footsteps'], ['34.946', '38.773', 'crowds'], ['38.773', '48.773', 'aircraft'], ['48.773', '58.633', 'car'], ['58.633', '68.084', 'rainforest'], ['68.084', '75.751', 'aircraft'], ['75.751', '80.37', 'clocks'], ['80.37', '83.271', 'car']]

# %%
audio_files = glob.glob("/content/extracted-data/outputs/*.wav")
# text_files = glob.glob("/content/extracted-data/outputs/*.txt")

# %%
os.makedirs(dirname(audio_files[0]).replace("outputs", "outputs-mono"))
# os.makedirs(dirname(text_files[0]).replace("outputs", "outputs-mono"))
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-109-b8c8656ce981> in <cell line: 1>()
# ----> 1 os.makedirs(dirname(audio_files[0]).replace("outputs", "outputs-mono"))
#       2 # os.makedirs(dirname(text_files[0]).replace("outputs", "outputs-mono"))
#
# /usr/lib/python3.9/os.py in makedirs(name, mode, exist_ok)
#     223             return
#     224     try:
# --> 225         mkdir(name, mode)
#     226     except OSError:
#     227         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [Errno 17] File exists: '/content/extracted-data/outputs-mono'

# %%
for sound in audio_files:
  temp_file = sound.replace("outputs", "outputs-mono")
  command = command = "sox " + sound + " " + temp_file + " channels 1"
  p = Popen(command, stdin=PIPE, stdout=PIPE, stderr=PIPE, shell=True)
  output, err = p.communicate()

# %%
audio_files_mono = glob.glob("/content/extracted-data/outputs-mono/*.wav")
random.shuffle(audio_files_mono)

# %%
print(audio_files_mono)
# Out:
# ['/content/extracted-data/outputs-mono/854.wav', '/content/extracted-data/outputs-mono/132.wav', '/content/extracted-data/outputs-mono/909.wav', '/content/extracted-data/outputs-mono/657.wav', '/content/extracted-data/outputs-mono/340.wav', '/content/extracted-data/outputs-mono/769.wav', '/content/extracted-data/outputs-mono/455.wav', '/content/extracted-data/outputs-mono/22.wav', '/content/extracted-data/outputs-mono/945.wav', '/content/extracted-data/outputs-mono/196.wav', '/content/extracted-data/outputs-mono/97.wav', '/content/extracted-data/outputs-mono/357.wav', '/content/extracted-data/outputs-mono/338.wav', '/content/extracted-data/outputs-mono/661.wav', '/content/extracted-data/outputs-mono/839.wav', '/content/extracted-data/outputs-mono/983.wav', '/content/extracted-data/outputs-mono/747.wav', '/content/extracted-data/outputs-mono/787.wav', '/content/extracted-data/outputs-mono/571.wav', '/content/extracted-data/outputs-mono/818.wav', '/content/extracted-data/outputs-mono/699.wav', '/content/extracted-data/outputs-mono/618.wav', '/content/extracted-data/outputs-mono/391.wav', '/content/extracted-data/outputs-mono/981.wav', '/content/extracted-data/outputs-mono/378.wav', '/content/extracted-data/outputs-mono/310.wav', '/content/extracted-data/outputs-mono/112.wav', '/content/extracted-data/outputs-mono/634.wav', '/content/extracted-data/outputs-mono/273.wav', '/content/extracted-data/outputs-mono/101.wav', '/content/extracted-data/outputs-mono/725.wav', '/content/extracted-data/outputs-mono/422.wav', '/content/extracted-data/outputs-mono/61.wav', '/content/extracted-data/outputs-mono/552.wav', '/content/extracted-data/outputs-mono/393.wav', '/content/extracted-data/outputs-mono/827.wav', '/content/extracted-data/outputs-mono/829.wav', '/content/extracted-data/outputs-mono/612.wav', '/content/extracted-data/outputs-mono/588.wav', '/content/extracted-data/outputs-mono/927.wav', '/content/extracted-data/outputs-mono/932.wav', '/content/extracted-data/outputs-mono/83.wav', '/content/extracted-data/outputs-mono/236.wav', '/content/extracted-data/outputs-mono/205.wav', '/content/extracted-data/outputs-mono/952.wav', '/content/extracted-data/outputs-mono/950.wav', '/content/extracted-data/outputs-mono/424.wav', '/content/extracted-data/outputs-mono/790.wav', '/content/extracted-data/outputs-mono/554.wav', '/content/extracted-data/outputs-mono/877.wav', '/content/extracted-data/outputs-mono/7.wav', '/content/extracted-data/outputs-mono/463.wav', '/content/extracted-data/outputs-mono/327.wav', '/content/extracted-data/outputs-mono/942.wav', '/content/extracted-data/outputs-mono/200.wav', '/content/extracted-data/outputs-mono/320.wav', '/content/extracted-data/outputs-mono/335.wav', '/content/extracted-data/outputs-mono/29.wav', '/content/extracted-data/outputs-mono/186.wav', '/content/extracted-data/outputs-mono/688.wav', '/content/extracted-data/outputs-mono/149.wav', '/content/extracted-data/outputs-mono/601.wav', '/content/extracted-data/outputs-mono/824.wav', '/content/extracted-data/outputs-mono/548.wav', '/content/extracted-data/outputs-mono/964.wav', '/content/extracted-data/outputs-mono/770.wav', '/content/extracted-data/outputs-mono/476.wav', '/content/extracted-data/outputs-mono/323.wav', '/content/extracted-data/outputs-mono/742.wav', '/content/extracted-data/outputs-mono/805.wav', '/content/extracted-data/outputs-mono/667.wav', '/content/extracted-data/outputs-mono/721.wav', '/content/extracted-data/outputs-mono/415.wav', '/content/extracted-data/outputs-mono/868.wav', '/content/extracted-data/outputs-mono/257.wav', '/content/extracted-data/outputs-mono/213.wav', '/content/extracted-data/outputs-mono/948.wav', '/content/extracted-data/outputs-mono/593.wav', '/content/extracted-data/outputs-mono/875.wav', '/content/extracted-data/outputs-mono/134.wav', '/content/extracted-data/outputs-mono/972.wav', '/content/extracted-data/outputs-mono/419.wav', '/content/extracted-data/outputs-mono/763.wav', '/content/extracted-da ...

# %% [markdown]
# # Split into folds

# %%
# fold1_train_events = convert_annotations_to_events("/content/development/TUT-sound-events-2017-development/evaluation_setup/street_fold1_train.txt")
# fold1_val_events = convert_annotations_to_events("/content/development/TUT-sound-events-2017-development/evaluation_setup/street_fold1_evaluate.txt")
# # using fold2 evaluate as test set
# fold1_test_events = convert_annotations_to_events("/content/development/TUT-sound-events-2017-development/evaluation_setup/street_fold2_evaluate.txt")
# # use only half of it
# fold1_test_events = fold1_test_events[:len(fold1_test_events) // 4]

# %%
# print('fold1_train_events:', len(fold1_train_events))
# print('fold1_val_events:', len(fold1_val_events))
# print('fold1_test_events:', len(fold1_test_events))

fold1_train_files = []
fold1_val_files = []
fold1_test_files = []
print(len(audio_files_mono))
audio_files_mono = audio_files_mono[:100]
i = 0
for f in audio_files_mono:
  if i < 70:
    fold1_train_files.append(f)
  elif i < 90:
    fold1_val_files.append(f)
  else:
    fold1_test_files.append(f)
  i+=1
# Out:
# 100

# %%
# fold1_train_files = set([f[0].replace("audio", "/content/development/TUT-sound-events-2017-development/audio-mono") for f in fold1_train_events])
# fold1_val_files = set([f[0].replace("audio", "/content/development/TUT-sound-events-2017-development/audio-mono") for f in fold1_val_events])
# fold1_test_files = set([f[0].replace("audio", "/content/development/TUT-sound-events-2017-development/audio-mono") for f in fold1_test_events])

# %%
def construct_examples(audio_path, win_len = 2.56, hop_len = 1.0, sr = 44100.0):
  # here win_len is the window_length and hop_len is the hop_length between the examples.
  # sr is the sampling rate

  window_length_t = win_len
  hop_length_t = hop_len

  window_length = int(sr*window_length_t)
  hop_length = int(sr*hop_length_t)

  audio, sr = sf.read(audio_path)

  # handle padding
  if audio.shape[0] < window_length:
    audio_padded = np.zeros((window_length, ))
    audio_padded[0:audio.shape[0]] = audio 

  else:
    no_of_hops = math.ceil((audio.shape[0] - window_length) / hop_length)
    audio_padded = np.zeros((int(window_length + hop_length*no_of_hops), ))
    audio_padded[0:audio.shape[0]] = audio  

  audio_example = [audio_padded[i - window_length : i] for i in range(window_length, audio_padded.shape[0]+1, hop_length)]
  win_ranges = [((i - window_length)/sr, i/sr) for i in range(window_length, audio_padded.shape[0]+1, hop_length)]

  return audio_example, win_ranges

# %%
def construct_labels(annotation_path, win_start, win_end, win_len):
  # takes the annotation_path, window_start, window_end and window_length
  events = convert_annotations_to_events(annotation_path)

  annotation_vals = [[float(e[0]), float(e[1]), e[2]] for e in events]

  curr_annotation = []

  for annotation in annotation_vals:
    if annotation[1] > win_start and annotation[0] <= win_end: 
      curr_start = max(annotation[0] - win_start, 0.0)
      curr_end = min(annotation[1] - win_start, win_len)
      curr_annotation.append([curr_start, curr_end, annotation[2]])    

  # get current class set from annotations
  class_set = set([c[2] for c in curr_annotation])
  class_wise_events = {}

  for c in list(class_set):
    class_wise_events[c] = []


  for c in curr_annotation:
    class_wise_events[c[2]].append(c)
    
  max_event_silence = 0.0
  all_events = []

  for k in list(class_wise_events.keys()):
    curr_events = class_wise_events[k]
    count = 0

    while count < len(curr_events) - 1:
      if (curr_events[count][1] >= curr_events[count + 1][0]) or (curr_events[count + 1][0] - curr_events[count][1] <= max_event_silence):
        curr_events[count][1] = max(curr_events[count + 1][1], curr_events[count][1])
        del curr_events[count + 1]
      else:
        count += 1

    all_events += curr_events

  for i in range(len(all_events)):
    # round all the values so that they are not arbitarily long
    all_events[i][0] = round(all_events[i][0], 3)
    all_events[i][1] = round(all_events[i][1], 3)

  all_events.sort(key=lambda x: x[0])

  return all_events

# %%
# def labels_by_class(events, class_dict, hop_len = 441, n_frames = 257, sr=44100): #seg...
#   labels = np.zeros((n_frames, len(class_dict)), dtype=np.float32)

#   for e in events:
#     t1 = float(e[0])
#     t1 = int(t1 / hop_len * sr)
#     t2 = float(e[1])
#     t2 = int(t2 / hop_len * sr)

#     labels[t1:t2, class_dict[e[2]]] = 1    
  
#   return labels

# %%
def get_universal_labels(events, class_dict, ex_length = 10.0, no_of_div = 32):
  # returns all labels from events
  win_length = ex_length/no_of_div
  labels = np.zeros((no_of_div, len(class_dict.keys()) * 3))
  
  for e in events:

    start_time = float(e[0])
    stop_time = float(e[1])
    if (float(e[0]) == 2.56):
      start_time = float(e[0] - 0.00001)
    if (float(e[1] == 2.56)):
      stop_time = float(e[1]- 0.000001)
     

    start_bin = int(start_time // win_length)
    stop_bin = int(stop_time // win_length)

    start_time_2 = start_time - start_bin * win_length
    stop_time_2 = stop_time - stop_bin * win_length

    n_bins = stop_bin - start_bin

    if n_bins == 0:
      labels[start_bin, class_dict[e[2]] * 3:class_dict[e[2]] * 3 + 3] = [1, start_time_2, stop_time_2]    

    elif n_bins == 1:
      labels[start_bin, class_dict[e[2]] * 3:class_dict[e[2]] * 3 + 3] = [1, start_time_2, win_length]

      if stop_time_2 > 0.0:
        labels[stop_bin, class_dict[e[2]] * 3:class_dict[e[2]] * 3 + 3] = [1, 0.0, stop_time_2]

    elif n_bins > 1:
      labels[start_bin, class_dict[e[2]] * 3:class_dict[e[2]] * 3 + 3] = [1, start_time_2, win_length]

      for i in range(1, n_bins):
        labels[start_bin + i, class_dict[e[2]] * 3:class_dict[e[2]] * 3 + 3] = [1, 0.0, win_length]

      if stop_time_2 > 0.0:
        labels[stop_bin, class_dict[e[2]] * 3:class_dict[e[2]] * 3 + 3] = [1, 0.0, stop_time_2]

  # divide all time values by window_length
  for labelIndex in range(len(labels)):
    for valIndex in range(len(labels[labelIndex])):
      if valIndex % 3 != 0:
        labels[labelIndex][valIndex] /= win_length

  return labels

# %%
CLASS_ENCODING = {"car": 0, "aircraft": 1, "crowds":2, "footsteps":3, "clocks":4, "rainforest": 5}

# %% [markdown]
# # Construct Datasets

# %%
def construct_data_set(fold_files, path):
  shutil.rmtree(path, ignore_errors=True)
  os.mkdir(path)

  window_length = 2.56
  hop_length = 1.0
  a_examples_train = []
  a_labels_train = []


  for i, audio in enumerate(fold_files):
    a, window_ranges = construct_examples(audio,win_len=window_length, hop_len=hop_length)
    a_examples_train += a

    for w in window_ranges:
      labels_t = construct_labels(audio.replace(".wav", ".txt").replace('outputs-mono', 'outputs'), w[0], w[1], win_len=window_length)
      ll = get_universal_labels(labels_t, CLASS_ENCODING, ex_length=window_length, no_of_div = 9)
      a_labels_train.append(ll)
  return a_examples_train, a_labels_train

# %%
examples_train, labels_train = construct_data_set(fold1_train_files, '/content/train-data')
examples_val, labels_val = construct_data_set(fold1_val_files, '/content/val-data')
examples_test, labels_test = construct_data_set(fold1_test_files, '/content/test-data')

# %%
print(fold1_val_files)
# Out:
# ['/content/extracted-data/outputs-mono/667.wav', '/content/extracted-data/outputs-mono/721.wav', '/content/extracted-data/outputs-mono/415.wav', '/content/extracted-data/outputs-mono/868.wav', '/content/extracted-data/outputs-mono/257.wav', '/content/extracted-data/outputs-mono/213.wav', '/content/extracted-data/outputs-mono/948.wav', '/content/extracted-data/outputs-mono/593.wav', '/content/extracted-data/outputs-mono/875.wav', '/content/extracted-data/outputs-mono/134.wav', '/content/extracted-data/outputs-mono/972.wav', '/content/extracted-data/outputs-mono/419.wav', '/content/extracted-data/outputs-mono/763.wav', '/content/extracted-data/outputs-mono/214.wav', '/content/extracted-data/outputs-mono/802.wav', '/content/extracted-data/outputs-mono/934.wav', '/content/extracted-data/outputs-mono/867.wav', '/content/extracted-data/outputs-mono/514.wav', '/content/extracted-data/outputs-mono/59.wav', '/content/extracted-data/outputs-mono/147.wav']

# %% [markdown]
# # Extract MelSpectrogram

# %%
def get_log_melspectrogram(audio, sr = 44100, hop_length = 441, win_length = 1764, n_fft = 2048, n_mels = 40, fmin = 0, fmax = 22050):
    """Return the log-scaled Mel bands of an audio signal."""
    audio_2 = librosa.util.normalize(audio)
    bands = librosa.feature.melspectrogram(
        y=audio_2, sr=sr, hop_length=hop_length, win_length = win_length, n_fft=n_fft, n_mels=n_mels)
    return librosa.core.power_to_db(bands)

# %%
# save melspectrograms for entire set
def save_example_mel(example_set, save_path):
  for i, audio in enumerate(example_set):
    M = get_log_melspectrogram(audio).T
    # print(M.shape)
    np.save(save_path + str(i) + ".npy", M)

# save labels in numpy format
def save_labels_np(label_set, save_path):
  for i, audio in enumerate(label_set):
    np.save(save_path + str(i) + ".npy", audio)

# %%
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# save labels for entire train set
train_path_ex = '/content/train-data/ex-'
train_path_labels = '/content/train-data/label-'
val_path_ex = '/content/val-data/ex-'
val_path_labels = '/content/val-data/label-'
test_path_ex = '/content/test-data/ex-'
test_path_labels = '/content/test-data/label-'



save_example_mel(examples_train, train_path_ex)
save_labels_np(labels_train, train_path_labels)
save_example_mel(examples_val, val_path_ex)
save_labels_np(labels_val, val_path_labels)
save_example_mel(examples_test, test_path_ex)
save_labels_np(labels_test, test_path_labels)

# %% [markdown]
# # Sort and Partition Datasets

# %%
def intOrVal(s):
    try:
        return int(s)
    except ValueError:
        return s
    
def alphanum_key(init_string):
    """ Turn a string into a list of string and number chunks.
        "z23a" -> ["z", 23, "a"]
    """
    return [intOrVal(c) for c in re.split('([0-9]+)', init_string)]

def sort_nicely(l):
    """ Sort the given list in the way that humans expect.
    """
    l.sort(key=alphanum_key)

# %%
def get_sorted_data(regex_path):
  data = glob.glob(regex_path) 
  sort_nicely(data)
  return data


"""
Load the individual numpy arrays into partition
"""
train_data_examples_regex_path = "/content/train-data/ex-*.npy"
train_data_labels_regex_path = "/content/train-data/label-*.npy"
val_data_examples_regex_path = "/content/val-data/ex-*.npy"
val_data_labels_regex_path = "/content/val-data/label-*.npy"
test_data_examples_regex_path = "/content/test-data/ex-*.npy"
test_data_labels_regex_path = "/content/test-data/label-*.npy"

train_data = get_sorted_data(train_data_examples_regex_path)
train_labels = get_sorted_data(train_data_labels_regex_path)

val_data = get_sorted_data(val_data_examples_regex_path)
val_labels = get_sorted_data(val_data_labels_regex_path)

test_data = get_sorted_data(test_data_examples_regex_path)
test_labels = get_sorted_data(test_data_labels_regex_path)

training_examples = [(train_data[i], train_labels[i]) for i in range(len(train_data))]
validation_examples = [(val_data[i], val_labels[i]) for i in range(len(val_data))]
test_examples = [(test_data[i], test_labels[i]) for i in range(len(test_data))]

# shuffle all training examples
random.seed(7)
random.shuffle(training_examples)
random.shuffle(validation_examples)
random.shuffle(test_examples)
partition = {}
partition['train'] = training_examples
partition['validation'] = validation_examples
partition['test'] = test_examples

# %% [markdown]
# # Setup Data Generators

# %%
class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_examples, batch_size=128, shuffle=True):
        # dim
        # self.dim = (1,)
        self.batch_size = batch_size
        self.list_examples = list_examples
        self.shuffle = shuffle

        # initial shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_examples) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_examples[k] for k in indexes]

        # Generate data
        X, Y = self.generate_data(list_IDs_temp)

        return X, Y
        
    def on_epoch_end(self):
      self.indexes = np.arange(len(self.list_examples))

      # shuffle indexes at end of epoch
      if self.shuffle == True:
          np.random.shuffle(self.indexes)

    def generate_data(self, list_IDs_temp):
        # 'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        X = np.empty([self.batch_size, 257, 40, 1], dtype=np.float64)
        Y = np.empty([self.batch_size, 9, 18], dtype=np.float64)

        # Generate data
        for i, ID in enumerate(list_IDs_temp):
          # Store sample
          # load npy array
          np_x = np.load(ID[0])

          X[i, :, :, 0] = np_x

          # load class label
          np_y = np.load(ID[1])
          Y[i, :, :] = np_y

        tau = X.shape[1]          
        v = X.shape[2]

        # frequency and time masking of X values
        warped_frequency_spectrogram = spec_augment_tensorflow.frequency_masking(X, v=v,  frequency_masking_para=8, frequency_mask_num=1)
        warped_frequency_time_spectrogram = spec_augment_tensorflow.time_masking(warped_frequency_spectrogram, tau=tau, time_masking_para=25, time_mask_num=2)

        X = warped_frequency_time_spectrogram

        return X, Y

# %%
# Parametersa
params = {'batch_size': 32, 'shuffle': True}

training_generator = DataGenerator(partition['train'], **params)
validation_generator = DataGenerator(partition['validation'], **params)
test_generator = DataGenerator(partition['test'], **params)

# %% [markdown]
# # Define the YOHO network

# %%
def square_difference_loss(y_true, y_pred):
  squared_difference = tf.square(y_true - y_pred)

  ss_True = squared_difference[:, :, 0] * 0 + 1 
  # ss_True is batchsize, window_len of 1s

  # get every 3 value of y_true
  ss_0 = y_true[:, :, 0]
  ss_1 = y_true[:, :, 3]
  ss_2 = y_true[:, :, 6]
  ss_3 = y_true[:, :, 9]
  ss_4 = y_true[:, :, 12]
  ss_5 = y_true[:, :, 15]
  # labels across all batch sizes

  # stack values
  stacked_ss = tf.stack((ss_True, ss_0, ss_0,
                         ss_True, ss_1, ss_1,
                         ss_True, ss_2, ss_2,
                         ss_True, ss_3, ss_3,
                         ss_True, ss_4, ss_4,
                         ss_True, ss_5, ss_5), axis = 2)
  
  squared_difference =  tf.multiply(squared_difference, stacked_ss)

  return tf.reduce_sum(squared_difference, axis=[-1, -2])

# %%
# Creates mel spctrograms for validation fold for training
def create_train_melspectrograms():
  win_length = 2.56
  hop_size = 1.96
  mss_ins = []
  win_ranges_list = []


  for ii, audio in enumerate(fold1_val_files): # why val?
    a, win_ranges = construct_examples(audio, win_len=win_length,hop_len=hop_size)

    mss_in = np.zeros((len(a), 257, 40))

    preds = np.zeros((len(a), 9, 18))

    for i in range(len(a)):
      M = get_log_melspectrogram(a[i])
      mss_in[i, :, :] = M.T
    mss_ins.append(mss_in)
    win_ranges_list.append(win_ranges)
  return mss_ins,win_ranges_list


BASE_MSS_INS, BASE_WIN_RANGE = create_train_melspectrograms()

def mk_preds_YOHO_mel(model, ind, window_range_list=BASE_WIN_RANGE, mss_ins=BASE_MSS_INS, no_of_div = 9, hop_size = 1.96, discard = 0.3, win_length = 2.56, max_event_silence = 0.3, sampling_rate = 44100):
  preds = model.predict(mss_ins[ind])
  events = []

  for i in range(len(preds)):
    p = preds[i, :, :]
    events_curr = []
    win_width = win_length / no_of_div
    for j in range(len(p)):
      for jjj in range(0, 6):
        if p[j][jjj*3] >= 0.5:
          start = win_width * j + win_width * p[j][jjj*3+1] + window_range_list[ind][i][0]
          end = p[j][jjj*3+2] * win_width + start
          events_curr.append([start, end, rev_class_list[jjj]])

    events += events_curr


  class_set = set([c[2] for c in events])
  class_wise_events = {}

  for c in list(class_set):
    class_wise_events[c] = []


  for c in events:
    class_wise_events[c[2]].append(c)
    
  
  all_events = []

  for k in list(class_wise_events.keys()):
    curr_events = class_wise_events[k]
    count = 0

    while count < len(curr_events) - 1:
      if (curr_events[count][1] >= curr_events[count + 1][0]) or (curr_events[count + 1][0] - curr_events[count][1] <= max_event_silence):
        curr_events[count][1] = max(curr_events[count + 1][1], curr_events[count][1])
        del curr_events[count + 1]
      else:
        count += 1

    all_events += curr_events

  for i in range(len(all_events)):
    all_events[i][0] = round(all_events[i][0], 3)
    all_events[i][1] = round(all_events[i][1], 3)

  all_events.sort(key=lambda x: x[0])

  return all_events

# %%
rev_class_list = list(CLASS_ENCODING.keys())
print(rev_class_list)
# Out:
# ['car', 'aircraft', 'crowds', 'footsteps', 'clocks', 'rainforest']

# %%
def frames_to_time(f, sr = 44100.0, hop_size = 441):
  return f * hop_size / sr

def preds_to_se(p, win_start, audio_clip_length = 2.56):
  start_dicts = [-100, -100, -100, -100, -100, -100]
  stop_dicts = [-100, -100, -100, -100, -100, -100]


  start_speech = -100
  start_music = -100
  stop_speech = -100
  stop_music = -100

  audio_events = []

  n_frames = p.shape[0]

  for j in range(p.shape[1]):
    if p[0, j] >= 0.5:
      start_dicts[j] = 0

  for j in range(p.shape[1]):
    for i in range(n_frames - 1):
      if p[i, j] < 0.5 and p[i+1, j] >= 0.5:
        start_dicts[j] = i+1

      elif p[i, j] >= 0.5 and p[i + 1, j] < 0.5:
        stop_dicts[j] = i
        start_time = frames_to_time(start_dicts[j])
        stop_time = frames_to_time(stop_dicts[j])

        audio_events.append([start_time+win_start, stop_time+win_start, rev_class_list[j]])
        start_dicts[j] = -100
        stop_dicts[j] = -100

    if start_dicts[j] != -100:
      start_time = frames_to_time(start_dicts[j])
      stop_time = audio_clip_length
      audio_events.append([start_time+win_start, stop_time+win_start, rev_class_list[j]])
      start_dicts[j] = -100
      stop_dicts[j] = -100

  audio_events.sort(key = lambda x: x[0]) 
  return audio_events

# %%
def extract_eval_labels_2(annotation_path):
  events = convert_annotations_to_events(annotation_path)

  ann = [[float(e[0]), float(e[1]), e[2]] for e in events]
  
  n_label = "/content/eval-files-2/" + os.path.basename(annotation_path)

  with open(n_label, 'w') as fp:
    fp.write('\n'.join('{},{},{}'.format(round(x[0], 5), round(x[1], 5), x[2]) for x in ann))

# %%
shutil.rmtree('/content/eval-files-2/', ignore_errors=True)
os.mkdir("/content/eval-files-2/")

# %%
for audio in fold1_val_files:
  extract_eval_labels_2(audio.replace(".wav", ".txt").replace("outputs-mono", "outputs"))

# %% [markdown]
# # Train Network

# %%
class KerasFinalCallback(tf.keras.callbacks.Callback):
  def __init__(self):
    super(KerasFinalCallback, self).__init__()
    self.best_f1 = 0.0
    self.best_error = np.inf
    
  def on_train_begin(self, logs=None):
    pass

  def on_train_end(self, logs=None):
    pass

  def on_epoch_end(self, epoch, logs=None):
    if epoch > 1:
      for ii, audio in enumerate(fold1_val_files):
        audio_file_path = audio
        see = mk_preds_YOHO_mel(self.model, ii)
        n_label = n_label = "/content/eval-files-2/" + os.path.basename(audio_file_path).replace(".wav" ,"") + "-se-prediction.txt"

        with open(n_label, 'w') as fp:
          fp.write('\n'.join('{},{},{}'.format(round(x[0], 5), round(x[1], 5), x[2]) for x in see))

      destination = "/content/eval-files-2/"
      test_set = glob.glob(destination + "*[0-9].txt")

      eval_path = "/content/"


      file_list = [
          {
          'reference_file': tt,
          'estimated_file': tt.replace(".txt","-se-prediction.txt")
          }
          for tt in test_set
      ]

      data = []

      # Get used event labels
      all_data = dcase_util.containers.MetaDataContainer()
      for file_pair in file_list:
          reference_event_list = sed_eval.io.load_event_list(
              filename=file_pair['reference_file']
          )
          estimated_event_list = sed_eval.io.load_event_list(
              filename=file_pair['estimated_file']
          )

          data.append({'reference_event_list': reference_event_list,
                      'estimated_event_list': estimated_event_list})

          all_data += reference_event_list

      event_labels = all_data.unique_event_labels

      # Start evaluating

      # Create metrics classes, define parameters
      segment_based_metrics = sed_eval.sound_event.SegmentBasedMetrics(
          event_label_list=event_labels,
          time_resolution=1.0
      )

      event_based_metrics = sed_eval.sound_event.EventBasedMetrics(
          event_label_list=event_labels,
          t_collar=1.0
      )

      # Go through files
      for file_pair in data:
          segment_based_metrics.evaluate(
              reference_event_list=file_pair['reference_event_list'],
              estimated_event_list=file_pair['estimated_event_list']
          )

          event_based_metrics.evaluate(
              reference_event_list=file_pair['reference_event_list'],
              estimated_event_list=file_pair['estimated_event_list']
          )

      # Get only certain metrics
      overall_segment_based_metrics = segment_based_metrics.results_overall_metrics()
      curr_f1 = overall_segment_based_metrics['f_measure']['f_measure']
      curr_error = overall_segment_based_metrics['error_rate']['error_rate']

      if curr_f1 > self.best_f1:
        self.best_f1 = curr_f1
        self.model.save_weights("/content/model-best-f1.h5")

      if curr_error < self.best_error:
        self.best_error = curr_error
        self.model.save_weights("/content/model-best-error.h5")

      print("F-measure: {:.3f} vs {:.3f}".format(curr_f1, self.best_f1))
      print("Error rate: {:.3f} vs {:.3f}".format(curr_error, self.best_error))

# %%
class YOHOBlock:
  def __init__(self, stride, num_filters, index, input):
      X = tf.keras.layers.DepthwiseConv2D(kernel_size=[3,3], strides = stride, depth_multiplier=1, padding='same', use_bias=False,
                                      activation=None, name="layer"+ str(index + 2)+"/depthwise_conv")(input)
      X = tf.keras.layers.BatchNormalization(center=True, scale=False, epsilon=1e-4, name = "layer"+ str(index + 2)+"/depthwise_conv/bn")(X)
      X = tf.keras.layers.ReLU(name="layer"+ str(index + 2)+"/depthwise_conv/relu")(X)
      X = tf.keras.layers.Conv2D(filters =num_filters, kernel_size=[1, 1], strides=1, padding='same', use_bias=False, activation=None,
                                name = "layer"+ str(index + 2)+"/pointwise_conv",
                                kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01))(X)
      X = tf.keras.layers.BatchNormalization(center=True, scale=False, epsilon=1e-4, name = "layer"+ str(index + 2)+"/pointwise_conv/bn")(X)
      self.output = tf.keras.layers.ReLU(name="layer"+ str(index + 2)+"/pointwise_conv/relu")(X)

class Network:
  def __init__(self) -> None:
    self.NETWORK_BLOCK_LAYERS = [
      # (stride, num_filters)
      (1,   64),
      (2,  128),
      (1,  128),
      (2,  256),
      (1,  256),
      (2,  512),
      (1,  512),
      (1,  512),
      (1,  512),
      (1,  512),
      (1,  512),
      (2, 1024),
      (1, 1024),
      (1, 512),
      (1, 256),
      (1, 128),
    ]
    self.m_features = tf.keras.Input(shape=(257, 40), name="mel_input")
    X = self.m_features
    X = tf.keras.layers.Reshape((257, 40, 1))(X)
    X = tf.keras.layers.Conv2D(filters = 32, kernel_size=[3, 3], strides=2, padding='same', use_bias=False,
                              activation=None, name = "layer1/conv",
                                kernel_regularizer=l2(1e-3), bias_regularizer=l2(1e-3))(X)
    X = tf.keras.layers.BatchNormalization(center=True, scale=False, epsilon=1e-4, name = "layer1/bn")(X)
    X = tf.keras.layers.ReLU(name="layer1/relu")(X)

    X = tf.keras.layers.SpatialDropout2D(0.1)(X)
    
    for index in range(len(self.NETWORK_BLOCK_LAYERS)):
      X = YOHOBlock(stride=self.NETWORK_BLOCK_LAYERS[index][0], num_filters=self.NETWORK_BLOCK_LAYERS[index][1], index=index, input=X).output

    _, _, sx, sy = X.shape
    X = tf.keras.layers.Reshape((-1, int(sx * sy)))(X)
    self.pred = tf.keras.layers.Conv1D(18, kernel_size=1, activation="sigmoid")(X)


model_arch = Network()
model = tf.keras.Model(
      name='YOHO', inputs=model_arch.m_features,outputs=[model_arch.pred])

# %%
model.summary()
# Out:
# Model: "YOHO"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mel_input (InputLayer)      [(None, 257, 40)]         0
#
#  reshape_10 (Reshape)        (None, 257, 40, 1)        0
#
#  layer1/conv (Conv2D)        (None, 129, 20, 32)       288
#
#  layer1/bn (BatchNormalizati  (None, 129, 20, 32)      96
#  on)
#
#  layer1/relu (ReLU)          (None, 129, 20, 32)       0
#
#  spatial_dropout2d_5 (Spatia  (None, 129, 20, 32)      0
#  lDropout2D)
#
#  layer2/depthwise_conv (Dept  (None, 129, 20, 32)      288
#  hwiseConv2D)
#
#  layer2/depthwise_conv/bn (B  (None, 129, 20, 32)      96
#  atchNormalization)
#
#  layer2/depthwise_conv/relu   (None, 129, 20, 32)      0
#  (ReLU)
#
#  layer2/pointwise_conv (Conv  (None, 129, 20, 64)      2048
#  2D)
#
#  layer2/pointwise_conv/bn (B  (None, 129, 20, 64)      192
#  atchNormalization)
#
#  layer2/pointwise_conv/relu   (None, 129, 20, 64)      0
#  (ReLU)
#
#  layer3/depthwise_conv (Dept  (None, 65, 10, 64)       576
#  hwiseConv2D)
#
#  layer3/depthwise_conv/bn (B  (None, 65, 10, 64)       192
#  atchNormalization)
#
#  layer3/depthwise_conv/relu   (None, 65, 10, 64)       0
#  (ReLU)
#
#  layer3/pointwise_conv (Conv  (None, 65, 10, 128)      8192
#  2D)
#
#  layer3/pointwise_conv/bn (B  (None, 65, 10, 128)      384
#  atchNormalization)
#
#  layer3/pointwise_conv/relu   (None, 65, 10, 128)      0
#  (ReLU)
#
#  layer4/depthwise_conv (Dept  (None, 65, 10, 128)      1152
#  hwiseConv2D)
#
#  layer4/depthwise_conv/bn (B  (None, 65, 10, 128)      384
#  atchNormalization)
#
#  layer4/depthwise_conv/relu   (None, 65, 10, 128)      0
#  (ReLU)
#
#  layer4/pointwise_conv (Conv  (None, 65, 10, 128)      16384
#  2D)
#
#  layer4/pointwise_conv/bn (B  (None, 65, 10, 128)      384
#  atchNormalization)
#
#  layer4/pointwise_conv/relu   (None, 65, 10, 128)      0
#  (ReLU)
#
#  layer5/depthwise_conv (Dept  (None, 33, 5, 128)       1152
#  hwiseConv2D)
#
#  layer5/depthwise_conv/bn (B  (None, 33, 5, 128)       384
#  atchNormalization)
#
#  layer5/depthwise_conv/relu   (None, 33, 5, 128)       0
#  (ReLU)
#
#  layer5/pointwise_conv (Conv  (None, 33, 5, 256)       32768
#  2D)
#
#  layer5/pointwise_conv/bn (B  (None, 33, 5, 256)       768
#  atchNormalization)
#
#  layer5/pointwise_conv/relu   (None, 33, 5, 256)       0
#  (ReLU)
#
#  layer6/depthwise_conv (Dept  (None, 33, 5, 256)       2304
#  hwiseConv2D)
#
#  layer6/depthwise_conv/bn (B  (None, 33, 5, 256)       768
#  atchNormalization)
#
#  layer6/depthwise_conv/relu   (None, 33, 5, 256)       0
#  (ReLU)
#
#  layer6/pointwise_conv (Conv  (None, 33, 5, 256)       65536
#  2D)
#
#  layer6/pointwise_conv/bn (B  (None, 33, 5, 256)       768
#  atchNormalization)
#
#  layer6/pointwise_conv/relu   (None, 33, 5, 256)       0
#  (ReLU)
#
#  layer7/depthwise_conv (Dept  (None, 17, 3, 256)       2304
#  hwiseConv2D)
#
#  layer7/depthwise_conv/bn (B  (None, 17, 3, 256)       768
#  atchNormalization)
#
#  layer7/depthwise_conv/relu   (None, 17, 3, 256)       0
#  (ReLU)
#
#  layer7/pointwise_conv (Conv  (None, 17, 3, 512)       131072
#  2D)
#
#  layer7/pointwise_conv/bn (B  (None, 17, 3, 512)       1536
#  atchNormalization)
#
#  layer7/pointwise_conv/relu   (None, 17, 3, 512)       0
#  (ReLU)
#
#  layer8/depthwise_conv (Dept  (None, 17, 3, 512)       4608
#  hwiseConv2D)
#
#  layer8/depthwise_conv/bn (B  (None, 17, 3, 512)       1536
#  atchNormalization)
#
#  layer8/depthwise_conv/relu   (None, 17, 3, 512)       0
#  (ReLU)
#
#  layer8/pointwise_conv (Conv  (None, 17, 3, 512)       262144
#  2D)
#
#  layer8/pointwise_conv/bn (B  (None, 17, 3, 512)       1536
#  atchNormalization)
#
#  layer8/pointwise_conv/relu   (None, 17, 3, 512)       0
#  (ReLU)
#
#  layer9/depthwise_conv (Dept  (None, 17, 3, 512)       4608
#  hwiseConv2D)
#
#  layer9/depthwise_conv/bn (B  (None, 17, 3, 512)       1536
#  atchNormalization)
#
#  layer9/depthwise_conv/relu   (None, 17, 3, 512)       0
#  (ReLU)
#
#  layer9/pointwise_conv (Conv  (None, 17, 3, 512)       262144
#  2D)
#
#  layer9/pointwise_conv/bn (B  (None, 17, 3, 512)       1536
#  atchNormalization)
#
#  layer9/pointwise_conv/relu   (None, 17, 3, 512)       0
#  (ReLU)
#
#  layer10/depthwise_conv (Dep  (None, 17, 3, 512)       4608
#  thwiseConv2D)
#
#  layer10/depthwise_conv/bn (  (None, 17, 3, 512)       1536
#  BatchNormalization)
#
#  layer10/depthwise_conv/relu  (None, 17, 3, 512)       0
#   (ReLU)
#
#  layer10/pointwise_conv (Con  (None, 17, 3, 512)       262144
#  v2D)
#
#  layer10/pointwise_conv/bn (  (None, 17, 3, 512)       1536
#  BatchNormalization)
#
#  layer10/pointwise_conv/relu  (None, 17, 3, 512)       0
#   (ReLU)
#
#  layer11/depthwise_conv (Dep  (None, 17, 3, 512)       4608
#  thwiseConv2D)
#
#  layer11/depthwise_conv/bn (  (None, 17, 3, 512)       1536
#  BatchNormalization)
#
#  layer11/depthwise_conv/relu  (None, 17, 3, 512)       0
#   (ReLU)
#
#  layer11/pointwise_conv (Con  (None, 17, 3, 512)       262144
#  v2D)
#
#  layer11/pointwise_conv/bn (  (None, 17, 3, 512)       1536
#  BatchNormalization)
#
#  layer11/pointwise_conv/relu  (None, 17, 3, 512)       0
#   (ReLU)
#
#  layer12/depthwise_conv (Dep  (None, 17, 3, 512)       4608
#  thwiseConv2D)
#
#  layer12/depthwise_conv/bn (  (None, 17, 3, 512)       1536
#  BatchNormalization)
#
#  layer12/depthwise_conv/relu  (None, 17, 3, 512)       0
#   (ReLU)
#
#  layer12/pointwise_conv (Con  (None, 17, 3, 512)       262144
#  v2D)
#
#  layer12/pointwise_conv/bn (  (None, 17, 3, 512)       1536
#  BatchNormalization)
#
#  layer12/pointwise_conv/relu  (None, 17, 3, 512)       0
#   (ReLU)
#
#  layer13/depthwise_conv (Dep  (None, 9, 2, 512)        4608
#  thwiseConv2D)
#
#  layer13/depthwise_conv/bn (  (None, 9, 2, 512)        1536
#  BatchNormalization)
#
#  layer13/depthwise_conv/relu  (None, 9, 2, 512)        0
#   (ReLU)
#
#  layer13/pointwise_conv (Con  (None, 9, 2, 1024)       524288
#  v2D)
#
#  layer13/pointwise_conv/bn (  (None, 9, 2, 1024)       3072
#  BatchNormalization)
#
#  layer13/pointwise_conv/relu  (None, 9, 2, 1024)       0
#   (ReLU)
#
#  layer14/depthwise_conv (Dep  (None, 9, 2, 1024)       9216
#  thwiseConv2D)
#
#  layer14/depthwise_conv/bn (  (None, 9, 2, 1024)       3072
#  BatchNormalization)
#
#  layer14/depthwise_conv/relu  (None, 9, 2, 1024)       0
#   (ReLU)
#
#  layer14/pointwise_conv (Con  (None, 9, 2, 1024)       1048576
#  v2D)
#
#  layer14/pointwise_conv/bn (  (None, 9, 2, 1024)       3072
#  BatchNormalization)
#
#  layer14/pointwise_conv/relu  (None, 9, 2, 1024)       0
#   (ReLU)
#
#  layer15/depthwise_conv (Dep  (None, 9, 2, 1024)       9216
#  thwiseConv2D)
#
#  layer15/depthwise_conv/bn (  (None, 9, 2, 1024)       3072
#  BatchNormalization)
#
#  layer15/depthwise_conv/relu  (None, 9, 2, 1024)       0
#   (ReLU)
#
#  layer15/pointwise_conv (Con  (None, 9, 2, 512)        524288
#  v2D)
#
#  layer15/pointwise_conv/bn (  (None, 9, 2, 512)        1536
#  BatchNormalization)
#
#  layer15/pointwise_conv/relu  (None, 9, 2, 512)        0
#   (ReLU)
#
#  layer16/depthwise_conv (Dep  (None, 9, 2, 512)        4608
#  thwiseConv2D)
#
#  layer16/depthwise_conv/bn (  (None, 9, 2, 512)        1536
#  BatchNormalization)
#
#  layer16/depthwise_conv/relu  (None, 9, 2, 512)        0
#   (ReLU)
#
#  layer16/pointwise_conv (Con  (None, 9, 2, 256)        131072
#  v2D)
#
#  layer16/pointwise_conv/bn (  (None, 9, 2, 256)        768
#  BatchNormalization)
#
#  layer16/pointwise_conv/relu  (None, 9, 2, 256)        0
#   (ReLU)
#
#  layer17/depthwise_conv (Dep  (None, 9, 2, 256)        2304
#  thwiseConv2D)
#
#  layer17/depthwise_conv/bn (  (None, 9, 2, 256)        768
#  BatchNormalization)
#
#  layer17/depthwise_conv/relu  (None, 9, 2, 256)        0
#   (ReLU)
#
#  layer17/pointwise_conv (Con  (None, 9, 2, 128)        32768
#  v2D)
#
#  layer17/pointwise_conv/bn (  (None, 9, 2, 128)        384
#  BatchNormalization)
#
#  layer17/pointwise_conv/relu  (None, 9, 2, 128)        0
#   (ReLU)
#
#  reshape_11 (Reshape)        (None, 9, 256)            0
#
#  conv1d_5 (Conv1D)           (None, 9, 18)             4626
#
# =================================================================
# Total params: 3,934,290
# Trainable params: 3,907,026
# Non-trainable params: 27,264
# _________________________________________________________________

# %%
learning_rate = 1e-3
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), 
              loss=square_difference_loss)

# %%
model.fit(training_generator, validation_data=validation_generator, epochs=1000, callbacks=[KerasFinalCallback()], verbose=1)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.916 vs 0.938
# Error rate: 0.140 vs 0.104
# 153/153 [==============================] - 10s 62ms/step - loss: 2.0760 - val_loss: 2.7241
# Epoch 793/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.909 vs 0.938
# Error rate: 0.150 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0117 - val_loss: 2.7597
# Epoch 794/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.912 vs 0.938
# Error rate: 0.137 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 1.9804 - val_loss: 2.6566
# Epoch 795/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.917 vs 0.938
# Error rate: 0.132 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 1.9628 - val_loss: 2.6094
# Epoch 796/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.913 vs 0.938
# Error rate: 0.142 vs 0.104
# 153/153 [==============================] - 10s 62ms/step - loss: 2.1072 - val_loss: 2.7345
# Epoch 797/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.911 vs 0.938
# Error rate: 0.142 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.1648 - val_loss: 2.7706
# Epoch 798/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.910 vs 0.938
# Error rate: 0.142 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0691 - val_loss: 2.6869
# Epoch 799/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.914 vs 0.938
# Error rate: 0.136 vs 0.104
# 153/153 [==============================] - 10s 67ms/step - loss: 1.9700 - val_loss: 2.5962
# Epoch 800/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.897 vs 0.938
# Error rate: 0.162 vs 0.104
# 153/153 [==============================] - 10s 64ms/step - loss: 1.9158 - val_loss: 2.8927
# Epoch 801/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.914 vs 0.938
# Error rate: 0.134 vs 0.104
# 153/153 [==============================] - 10s 64ms/step - loss: 2.0940 - val_loss: 2.6091
# Epoch 802/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.899 vs 0.938
# Error rate: 0.159 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0178 - val_loss: 2.7144
# Epoch 803/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.916 vs 0.938
# Error rate: 0.137 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0530 - val_loss: 2.7054
# Epoch 804/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.907 vs 0.938
# Error rate: 0.143 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0026 - val_loss: 2.7326
# Epoch 805/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.919 vs 0.938
# Error rate: 0.125 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0381 - val_loss: 2.5757
# Epoch 806/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.915 vs 0.938
# Error rate: 0.134 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0109 - val_loss: 2.5090
# Epoch 807/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.917 vs 0.938
# Error rate: 0.129 vs 0.104
# 153/153 [==============================] - 10s 62ms/step - loss: 2.0402 - val_loss: 2.6997
# Epoch 808/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.898 vs 0.938
# Error rate: 0.160 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 1.9441 - val_loss: 2.7368
# Epoch 809/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.898 vs 0.938
# Error rate: 0.166 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 1.9703 - val_loss: 2.7122
# Epoch 810/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.913 vs 0.938
# Error rate: 0.141 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0834 - val_loss: 2.5392
# Epoch 811/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.872 vs 0.938
# Error rate: 0.198 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 1.9646 - val_loss: 3.1359
# Epoch 812/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.917 vs 0.938
# Error rate: 0.131 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.1122 - val_loss: 2.6207
# Epoch 813/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.908 vs 0.938
# Error rate: 0.142 vs 0.104
# 153/153 [==============================] - 10s 62ms/step - loss: 2.0657 - val_loss: 2.6223
# Epoch 814/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.894 vs 0.938
# Error rate: 0.162 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.1167 - val_loss: 2.9753
# Epoch 815/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.917 vs 0.938
# Error rate: 0.131 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0304 - val_loss: 2.5450
# Epoch 816/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.917 vs 0.938
# Error rate: 0.134 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 1.9625 - val_loss: 2.6477
# Epoch 817/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.918 vs 0.938
# Error rate: 0.126 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0045 - val_loss: 2.6741
# Epoch 818/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.902 vs 0.938
# Error rate: 0.153 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0398 - val_loss: 3.0045
# Epoch 819/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.925 vs 0.938
# Error rate: 0.118 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0463 - val_loss: 2.5209
# Epoch 820/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.918 vs 0.938
# Error rate: 0.129 vs 0.104
# 153/153 [==============================] - 10s 62ms/step - loss: 2.1065 - val_loss: 2.7943
# Epoch 821/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.922 vs 0.938
# Error rate: 0.125 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.1250 - val_loss: 2.6671
# Epoch 822/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.909 vs 0.938
# Error rate: 0.145 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0514 - val_loss: 2.7989
# Epoch 823/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.926 vs 0.938
# Error rate: 0.125 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0203 - val_loss: 2.5331
# Epoch 824/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.902 vs 0.938
# Error rate: 0.159 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 1.9993 - val_loss: 2.8304
# Epoch 825/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.925 vs 0.938
# Error rate: 0.121 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0449 - val_loss: 2.5061
# Epoch 826/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.917 vs 0.938
# Error rate: 0.136 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0090 - val_loss: 2.6821
# Epoch 827/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.918 vs 0.938
# Error rate: 0.132 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0451 - val_loss: 2.7180
# Epoch 828/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.897 vs 0.938
# Error rate: 0.161 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0327 - val_loss: 2.9395
# Epoch 829/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.917 vs 0.938
# Error rate: 0.128 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 1.9947 - val_loss: 2.7739
# Epoch 830/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.926 vs 0.938
# Error rate: 0.121 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0391 - val_loss: 2.5603
# Epoch 831/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.921 vs 0.938
# Error rate: 0.129 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 1.9747 - val_loss: 2.7417
# Epoch 832/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.922 vs 0.938
# Error rate: 0.127 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 1.9908 - val_loss: 2.4929
# Epoch 833/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# ...
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.915 vs 0.938
# Error rate: 0.136 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0029 - val_loss: 2.4449
# Epoch 988/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.914 vs 0.938
# Error rate: 0.134 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0217 - val_loss: 2.6816
# Epoch 989/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.907 vs 0.938
# Error rate: 0.143 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 1.9713 - val_loss: 2.8051
# Epoch 990/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.908 vs 0.938
# Error rate: 0.146 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0496 - val_loss: 2.6856
# Epoch 991/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.908 vs 0.938
# Error rate: 0.131 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 1.9778 - val_loss: 2.7778
# Epoch 992/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.907 vs 0.938
# Error rate: 0.143 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 1.8660 - val_loss: 2.6998
# Epoch 993/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.893 vs 0.938
# Error rate: 0.170 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 1.9718 - val_loss: 2.7499
# Epoch 994/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.918 vs 0.938
# Error rate: 0.132 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 2.0154 - val_loss: 2.6374
# Epoch 995/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 11ms/step
# F-measure: 0.899 vs 0.938
# Error rate: 0.154 vs 0.104
# 153/153 [==============================] - 10s 67ms/step - loss: 1.9777 - val_loss: 2.8226
# Epoch 996/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.907 vs 0.938
# Error rate: 0.143 vs 0.104
# 153/153 [==============================] - 10s 64ms/step - loss: 1.9592 - val_loss: 2.6138
# Epoch 997/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.917 vs 0.938
# Error rate: 0.132 vs 0.104
# 153/153 [==============================] - 10s 65ms/step - loss: 1.9532 - val_loss: 2.7055
# Epoch 998/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.894 vs 0.938
# Error rate: 0.159 vs 0.104
# 153/153 [==============================] - 10s 64ms/step - loss: 1.9797 - val_loss: 2.7120
# Epoch 999/1000
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# F-measure: 0.904 vs 0.938
# Error rate: 0.145 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 1.9780 - val_loss: 2.7027
# Epoch 1000/1000
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# F-measure: 0.916 vs 0.938
# Error rate: 0.131 vs 0.104
# 153/153 [==============================] - 10s 63ms/step - loss: 1.9400 - val_loss: 2.5031

# %%
loss = model.evaluate(test_generator)# callbacks=[KerasFinalCallback()])
print('loss:', loss)
# print('accuracy:', accuracy)
# Out:
# 22/22 [==============================] - 1s 36ms/step - loss: 4.6073
# loss: 4.607277870178223
