# %% [markdown]
# # Initial Imports

# %%
from zipfile import ZipFile
import glob
import csv
import random
from subprocess import Popen, PIPE
from keras import regularizers
from os.path import dirname
import os
import soundfile as sf
# !sudo apt-get install sox
import math
import numpy as np
import librosa
import shutil
import pickle
import re
import tensorflow as tf
# !git clone https://github.com/DemisEom/SpecAugment.git
# !pip install /content/SpecAugment/ --quiet
# !pip install tensorflow-addons --quiet
# !pip install sed_eval --quiet
import keras
from SpecAugment import spec_augment_tensorflow
import sed_eval
import dcase_util
from keras import regularizers
from keras.regularizers import l2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base
#   libsox3
# Suggested packages:
#   libsox-fmt-all
# The following NEW packages will be installed:
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base
#   libsox3 sox
# 0 upgraded, 6 newly installed, 0 to remove and 23 not upgraded.
# Need to get 513 kB of archives.
# After this operation, 1,564 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrnb0 amd64 0.1.5-1 [94.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrwb0 amd64 0.1.5-1 [49.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsox3 amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [225 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsox-fmt-alsa amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [10.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsox-fmt-base amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [31.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 sox amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [102 kB]
# Fetched 513 kB in 1s (671 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 6.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libopencore-amrnb0:amd64.
# (Reading database ... 128288 files and directories currently installed.)
# Preparing to unpack .../0-libopencore-amrnb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../1-libopencore-amrwb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libsox3:amd64.
# Preparing to unpack .../2-libsox3_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking libsox3:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Selecting previously unselected package libsox-fmt-alsa:amd64.
# Preparing to unpack .../3-libsox-fmt-alsa_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking libsox-fmt-alsa:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Selecting previously unselected package libsox-fmt-base:amd64.
# Preparing to unpack .../4-libsox-fmt-base_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking libsox-fmt-base:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Selecting previously unselected package sox.
# Preparing to unpack .../5-sox_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking sox (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up libsox3:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up libopencore-amrwb0:amd64 (0.1.5-1) ...
# Setting up libsox-fmt-alsa:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up libopencore-amrnb0:amd64 (0.1.5-1) ...
# Setting up libsox-fmt-base:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up sox (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Cloning into 'SpecAugment'...
# remote: Enumerating objects: 271, done.
# remote: Total 271 (delta 0), reused 0 (delta 0), pack-reused 271
# Receiving objects: 100% (271/271), 429.45 KiB | 16.52 MiB/s, done.
# Resolving deltas: 100% (150/150), done.
#   Preparing metadata (setup.py) ... done
#   Building wheel for SpecAugment (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 46.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 70.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Building wheel for sed_eval (setup.py) ... done
#   Building wheel for dcase_util (setup.py) ... done
#   Building wheel for validators (setup.py) ... done
# /usr/local/lib/python3.9/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.12.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %% [markdown]
# # Download Development Dataset (Train/Val)

# %%
def download_train_data():
  download_path = "/content/datasetZipped/"
  # !mkdir $download_path
  # get first both audio set zips
  # !wget https://zenodo.org/record/814831/files/TUT-sound-events-2017-development.audio.1.zip?download=1 -O {download_path}TUT-sound-events-2017-development.audio.1.zip
  # !wget https://zenodo.org/record/814831/files/TUT-sound-events-2017-development.audio.2.zip?download=1 -O {download_path}TUT-sound-events-2017-development.audio.2.zip
  # download labels and related metadata
  # !wget https://zenodo.org/record/814831/files/TUT-sound-events-2017-development.doc.zip?download=1 -O {download_path}TUT-sound-events-2017-development.doc.zip
  # !wget https://zenodo.org/record/814831/files/TUT-sound-events-2017-development.meta.zip?download=1 -O {download_path}TUT-sound-events-2017-development.meta.zip

# %%
# Download the actual data
download_train_data()
# Out:
# --2023-03-31 22:56:21--  https://zenodo.org/record/814831/files/TUT-sound-events-2017-development.audio.1.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1062653169 (1013M) [application/octet-stream]
# Saving to: ‘/content/datasetZipped/TUT-sound-events-2017-development.audio.1.zip’
#
# /content/datasetZip 100%[===================>]   1013M  29.0MB/s    in 36s
#
# 2023-03-31 22:56:59 (28.1 MB/s) - ‘/content/datasetZipped/TUT-sound-events-2017-development.audio.1.zip’ saved [1062653169/1062653169]
#
# --2023-03-31 22:56:59--  https://zenodo.org/record/814831/files/TUT-sound-events-2017-development.audio.2.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 213232458 (203M) [application/octet-stream]
# Saving to: ‘/content/datasetZipped/TUT-sound-events-2017-development.audio.2.zip’
#
# /content/datasetZip 100%[===================>] 203.35M  28.8MB/s    in 7.8s
#
# 2023-03-31 22:57:08 (26.1 MB/s) - ‘/content/datasetZipped/TUT-sound-events-2017-development.audio.2.zip’ saved [213232458/213232458]
#
# --2023-03-31 22:57:08--  https://zenodo.org/record/814831/files/TUT-sound-events-2017-development.doc.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56150 (55K) [application/octet-stream]
# Saving to: ‘/content/datasetZipped/TUT-sound-events-2017-development.doc.zip’
#
# /content/datasetZip 100%[===================>]  54.83K  --.-KB/s    in 0.1s
#
# 2023-03-31 22:57:09 (547 KB/s) - ‘/content/datasetZipped/TUT-sound-events-2017-development.doc.zip’ saved [56150/56150]
#
# --2023-03-31 22:57:09--  https://zenodo.org/record/814831/files/TUT-sound-events-2017-development.meta.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 140684 (137K) [application/octet-stream]
# Saving to: ‘/content/datasetZipped/TUT-sound-events-2017-development.meta.zip’
#
# /content/datasetZip 100%[===================>] 137.39K   456KB/s    in 0.3s
#
# 2023-03-31 22:57:10 (456 KB/s) - ‘/content/datasetZipped/TUT-sound-events-2017-development.meta.zip’ saved [140684/140684]

# %% [markdown]
# # Download Test Dataset

# %%
def download_test_data():
  download_path = "/content/EvaluationZipped/"
  # !mkdir $download_path
  # get the audio set zip
  # !wget https://zenodo.org/record/1040179/files/TUT-sound-events-2017-evaluation.audio.zip?download=1 -O {download_path}TUT-sound-events-2017-evaluation.audio.zip  
  # download labels and related metadata
  # !wget https://zenodo.org/record/1040179/files/TUT-sound-events-2017-evaluation.doc.zip?download=1 -O {download_path}TUT-sound-events-2017-evaluation.doc.zip
  # !wget https://zenodo.org/record/1040179/files/TUT-sound-events-2017-evaluation.meta.zip?download=1 -O {download_path}TUT-sound-events-2017-evaluation.meta.zip

# %%
download_test_data()
# Out:
# --2023-03-31 22:57:13--  https://zenodo.org/record/1040179/files/TUT-sound-events-2017-evaluation.audio.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 388173790 (370M) [application/octet-stream]
# Saving to: ‘/content/EvaluationZipped/TUT-sound-events-2017-evaluation.audio.zip’
#
# /content/Evaluation 100%[===================>] 370.19M  28.9MB/s    in 14s
#
# 2023-03-31 22:57:27 (27.2 MB/s) - ‘/content/EvaluationZipped/TUT-sound-events-2017-evaluation.audio.zip’ saved [388173790/388173790]
#
# --2023-03-31 22:57:27--  https://zenodo.org/record/1040179/files/TUT-sound-events-2017-evaluation.doc.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55462 (54K) [application/octet-stream]
# Saving to: ‘/content/EvaluationZipped/TUT-sound-events-2017-evaluation.doc.zip’
#
# /content/Evaluation 100%[===================>]  54.16K  --.-KB/s    in 0.1s
#
# 2023-03-31 22:57:28 (529 KB/s) - ‘/content/EvaluationZipped/TUT-sound-events-2017-evaluation.doc.zip’ saved [55462/55462]
#
# --2023-03-31 22:57:28--  https://zenodo.org/record/1040179/files/TUT-sound-events-2017-evaluation.meta.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14147 (14K) [application/octet-stream]
# Saving to: ‘/content/EvaluationZipped/TUT-sound-events-2017-evaluation.meta.zip’
#
# /content/Evaluation 100%[===================>]  13.82K  --.-KB/s    in 0s
#
# 2023-03-31 22:57:29 (207 MB/s) - ‘/content/EvaluationZipped/TUT-sound-events-2017-evaluation.meta.zip’ saved [14147/14147]

# %% [markdown]
# #Unzip all The data

# %%
def unzip_data(download_path, extract_path):
  download_path = "/content/datasetZipped/"

  # create glob
  final_glob = glob.glob(f"{download_path}*.zip")

  for zip_name in final_glob:
    with ZipFile(zip_name, 'r') as zip:
      zip.extractall(extract_path)

# %%
download_development_path = '/content/datasetZipped/'
extract_development_path = '/content/development'
download_test_path = '/content/EvaluationZipped/'
extract_test_path = '/content/evaluation'

unzip_data(download_development_path, extract_development_path)
unzip_data(download_test_path, extract_test_path)

# %% [markdown]
# # Extract Annotations

# %%
def convert_annotations_to_events(filename): #read_annotations
    events = []
    with open(filename, 'r') as csvfile:
        spamreader = csv.reader(csvfile, delimiter='\t', quotechar='|')
        for row in spamreader:
            events.append(row)
    return events

# %%
events = convert_annotations_to_events("/content/development/TUT-sound-events-2017-development/meta/street/a001.ann")

# %%
audio_files = glob.glob("/content/development/TUT-sound-events-2017-development/audio/street/*.wav")

# %%
os.makedirs(dirname(audio_files[0]).replace("audio", "audio-mono"))

# %%
for sound in audio_files:
  temp_file = sound.replace("audio", "audio-mono")
  command = command = "sox " + sound + " " + temp_file + " channels 1"
  p = Popen(command, stdin=PIPE, stdout=PIPE, stderr=PIPE, shell=True)
  output, err = p.communicate()

# %%
audio_files_mono = glob.glob("/content/development/TUT-sound-events-2017-development/audio-mono/street/*.wav")

# %% [markdown]
# # Split into folds

# %%
fold1_train_events = convert_annotations_to_events("/content/development/TUT-sound-events-2017-development/evaluation_setup/street_fold1_train.txt")
fold1_val_events = convert_annotations_to_events("/content/development/TUT-sound-events-2017-development/evaluation_setup/street_fold1_evaluate.txt")
# using fold2 evaluate as test set
fold1_test_events = convert_annotations_to_events("/content/development/TUT-sound-events-2017-development/evaluation_setup/street_fold2_evaluate.txt")
# use only half of it
fold1_test_events = fold1_test_events[:len(fold1_test_events) // 4]

# %%
print('fold1_train_events:', len(fold1_train_events))
print('fold1_val_events:', len(fold1_val_events))
print('fold1_test_events:', len(fold1_test_events))
# Out:
# fold1_train_events: 535
# fold1_val_events: 124
# fold1_test_events: 42

# %%
fold1_train_files = set([f[0].replace("audio", "/content/development/TUT-sound-events-2017-development/audio-mono") for f in fold1_train_events])
fold1_val_files = set([f[0].replace("audio", "/content/development/TUT-sound-events-2017-development/audio-mono") for f in fold1_val_events])
fold1_test_files = set([f[0].replace("audio", "/content/development/TUT-sound-events-2017-development/audio-mono") for f in fold1_test_events])

# %%
def construct_examples(audio_path, win_len = 2.56, hop_len = 1.0, sr = 44100.0):
  # here win_len is the window_length and hop_len is the hop_length between the examples.
  # sr is the sampling rate

  window_length_t = win_len
  hop_length_t = hop_len

  window_length = int(sr*window_length_t)
  hop_length = int(sr*hop_length_t)

  audio, sr = sf.read(audio_path)

  # handle padding
  if audio.shape[0] < window_length:
    audio_padded = np.zeros((window_length, ))
    audio_padded[0:audio.shape[0]] = audio 

  else:
    no_of_hops = math.ceil((audio.shape[0] - window_length) / hop_length)
    audio_padded = np.zeros((int(window_length + hop_length*no_of_hops), ))
    audio_padded[0:audio.shape[0]] = audio  

  audio_example = [audio_padded[i - window_length : i] for i in range(window_length, audio_padded.shape[0]+1, hop_length)]
  win_ranges = [((i - window_length)/sr, i/sr) for i in range(window_length, audio_padded.shape[0]+1, hop_length)]

  return audio_example, win_ranges

# %%
def construct_labels(annotation_path, win_start, win_end, win_len):
  # takes the annotation_path, window_start, window_end and window_length
  events = convert_annotations_to_events(annotation_path)

  annotation_vals = [[float(e[2]), float(e[3]), e[4]] for e in events]

  curr_annotation = []

  for annotation in annotation_vals:
    if annotation[1] > win_start and annotation[0] <= win_end: 
      curr_start = max(annotation[0] - win_start, 0.0)
      curr_end = min(annotation[1] - win_start, win_len)
      curr_annotation.append([curr_start, curr_end, annotation[2]])    

  # get current class set from annotations
  class_set = set([c[2] for c in curr_annotation])
  class_wise_events = {}

  for c in list(class_set):
    class_wise_events[c] = []


  for c in curr_annotation:
    class_wise_events[c[2]].append(c)
    
  max_event_silence = 0.0
  all_events = []

  for k in list(class_wise_events.keys()):
    curr_events = class_wise_events[k]
    count = 0

    while count < len(curr_events) - 1:
      if (curr_events[count][1] >= curr_events[count + 1][0]) or (curr_events[count + 1][0] - curr_events[count][1] <= max_event_silence):
        curr_events[count][1] = max(curr_events[count + 1][1], curr_events[count][1])
        del curr_events[count + 1]
      else:
        count += 1

    all_events += curr_events

  for i in range(len(all_events)):
    # round all the values so that they are not arbitarily long
    all_events[i][0] = round(all_events[i][0], 3)
    all_events[i][1] = round(all_events[i][1], 3)

  all_events.sort(key=lambda x: x[0])

  return all_events

# %%
# def labels_by_class(events, class_dict, hop_len = 441, n_frames = 257, sr=44100): #seg...
#   labels = np.zeros((n_frames, len(class_dict)), dtype=np.float32)

#   for e in events:
#     t1 = float(e[0])
#     t1 = int(t1 / hop_len * sr)
#     t2 = float(e[1])
#     t2 = int(t2 / hop_len * sr)

#     labels[t1:t2, class_dict[e[2]]] = 1    
  
#   return labels

# %%
def get_universal_labels(events, class_dict, ex_length = 10.0, no_of_div = 32):
  # returns all labels from events
  win_length = ex_length/no_of_div
  labels = np.zeros((no_of_div, len(class_dict.keys()) * 3))
  
  for e in events:

    start_time = float(e[0])
    stop_time = float(e[1])

    start_bin = int(start_time // win_length)
    stop_bin = int(stop_time // win_length)

    start_time_2 = start_time - start_bin * win_length
    stop_time_2 = stop_time - stop_bin * win_length

    n_bins = stop_bin - start_bin

    if n_bins == 0:
      labels[start_bin, class_dict[e[2]] * 3:class_dict[e[2]] * 3 + 3] = [1, start_time_2, stop_time_2]    

    elif n_bins == 1:
      labels[start_bin, class_dict[e[2]] * 3:class_dict[e[2]] * 3 + 3] = [1, start_time_2, win_length]

      if stop_time_2 > 0.0:
        labels[stop_bin, class_dict[e[2]] * 3:class_dict[e[2]] * 3 + 3] = [1, 0.0, stop_time_2]

    elif n_bins > 1:
      labels[start_bin, class_dict[e[2]] * 3:class_dict[e[2]] * 3 + 3] = [1, start_time_2, win_length]

      for i in range(1, n_bins):
        labels[start_bin + i, class_dict[e[2]] * 3:class_dict[e[2]] * 3 + 3] = [1, 0.0, win_length]

      if stop_time_2 > 0.0:
        labels[stop_bin, class_dict[e[2]] * 3:class_dict[e[2]] * 3 + 3] = [1, 0.0, stop_time_2]

  # divide all time values by window_length
  for labelIndex in range(len(labels)):
    for valIndex in range(len(labels[labelIndex])):
      if valIndex % 3 != 0:
        labels[labelIndex][valIndex] /= win_length

  return labels

# %%
CLASS_ENCODING = {'brakes squeaking': 0,
                  'car': 1,
                  'children': 2,
                  'large vehicle': 3,
                  'people speaking': 4,
                  'people walking': 5}

# %% [markdown]
# # Construct Datasets

# %%
def construct_data_set(fold_files, path):
  shutil.rmtree(path, ignore_errors=True)
  os.mkdir(path)

  window_length = 2.56
  hop_length = 1.96
  a_examples_train = []
  a_labels_train = []


  for i, audio in enumerate(fold_files):
    a, window_ranges = construct_examples(audio,win_len=window_length, hop_len=hop_length)
    a_examples_train += a

    for w in window_ranges:
      labels_t = construct_labels(audio.replace(".wav", ".ann").replace("audio-mono", "meta"), w[0], w[1], win_len=window_length)
      ll = get_universal_labels(labels_t, CLASS_ENCODING, ex_length=window_length, no_of_div = 9)
      a_labels_train.append(ll)
  return a_examples_train, a_labels_train

# %%
examples_train, labels_train = construct_data_set(fold1_train_files, '/content/train-data')
examples_val, labels_val = construct_data_set(fold1_val_files, '/content/val-data')

# %%
examples_test, labels_test = construct_data_set(fold1_test_files, '/content/test-data')

# %% [markdown]
# # Extract MelSpectrogram

# %%
def get_log_melspectrogram(audio, sr = 44100, hop_length = 441, win_length = 1764, n_fft = 2048, n_mels = 40, fmin = 0, fmax = 22050):
    """Return the log-scaled Mel bands of an audio signal."""
    audio_2 = librosa.util.normalize(audio)
    bands = librosa.feature.melspectrogram(
        y=audio_2, sr=sr, hop_length=hop_length, win_length = win_length, n_fft=n_fft, n_mels=n_mels)
    return librosa.core.power_to_db(bands)

# %%
# save melspectrograms for entire set
def save_example_mel(example_set, save_path):
  for i, audio in enumerate(example_set):
    M = get_log_melspectrogram(audio).T
    # print(M.shape)
    np.save(save_path + str(i) + ".npy", M)

# save labels in numpy format
def save_labels_np(label_set, save_path):
  for i, audio in enumerate(label_set):
    np.save(save_path + str(i) + ".npy", audio)

# %%
# save labels for entire train set
train_path_ex = '/content/train-data/ex-'
train_path_labels = '/content/train-data/label-'
val_path_ex = '/content/val-data/ex-'
val_path_labels = '/content/val-data/label-'
test_path_ex = '/content/test-data/ex-'
test_path_labels = '/content/test-data/label-'

save_example_mel(examples_train, train_path_ex)
save_labels_np(labels_train, train_path_labels)
save_example_mel(examples_val, val_path_ex)
save_labels_np(labels_val, val_path_labels)
save_example_mel(examples_test, test_path_ex)
save_labels_np(labels_test, test_path_labels)

# %% [markdown]
# # Sort and Partition Datasets

# %%
def intOrVal(s):
    try:
        return int(s)
    except ValueError:
        return s
    
def alphanum_key(init_string):
    """ Turn a string into a list of string and number chunks.
        "z23a" -> ["z", 23, "a"]
    """
    return [intOrVal(c) for c in re.split('([0-9]+)', init_string)]

def sort_nicely(l):
    """ Sort the given list in the way that humans expect.
    """
    l.sort(key=alphanum_key)

# %%
def get_sorted_data(regex_path):
  data = glob.glob(regex_path) 
  sort_nicely(data)
  return data


"""
Load the individual numpy arrays into partition
"""
train_data_examples_regex_path = "/content/train-data/ex-*.npy"
train_data_labels_regex_path = "/content/train-data/label-*.npy"
val_data_examples_regex_path = "/content/val-data/ex-*.npy"
val_data_labels_regex_path = "/content/val-data/label-*.npy"
test_data_examples_regex_path = "/content/test-data/ex-*.npy"
test_data_labels_regex_path = "/content/test-data/label-*.npy"

train_data = get_sorted_data(train_data_examples_regex_path)
train_labels = get_sorted_data(train_data_labels_regex_path)

val_data = get_sorted_data(val_data_examples_regex_path)
val_labels = get_sorted_data(val_data_labels_regex_path)

test_data = get_sorted_data(test_data_examples_regex_path)
test_labels = get_sorted_data(test_data_labels_regex_path)

training_examples = [(train_data[i], train_labels[i]) for i in range(len(train_data))]
validation_examples = [(val_data[i], val_labels[i]) for i in range(len(val_data))]
test_examples = [(test_data[i], test_labels[i]) for i in range(len(test_data))]

# shuffle all training examples
random.seed(7)
random.shuffle(training_examples)
random.shuffle(validation_examples)
random.shuffle(test_examples)
partition = {}
partition['train'] = training_examples
partition['validation'] = validation_examples
partition['test'] = test_examples

# %% [markdown]
# # Setup Data Generators

# %%
class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_examples, batch_size=128, shuffle=True):
        # dim
        # self.dim = (1,)
        self.batch_size = batch_size
        self.list_examples = list_examples
        self.shuffle = shuffle

        # initial shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_examples) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_examples[k] for k in indexes]

        # Generate data
        X, Y = self.generate_data(list_IDs_temp)

        return X, Y
        
    def on_epoch_end(self):
      self.indexes = np.arange(len(self.list_examples))

      # shuffle indexes at end of epoch
      if self.shuffle == True:
          np.random.shuffle(self.indexes)

    def generate_data(self, list_IDs_temp):
        # 'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        X = np.empty([self.batch_size, 257, 40, 1], dtype=np.float64)
        Y = np.empty([self.batch_size, 9, 18], dtype=np.float64)

        # Generate data
        for i, ID in enumerate(list_IDs_temp):
          # Store sample
          # load npy array
          np_x = np.load(ID[0])

          X[i, :, :, 0] = np_x

          # load class label
          np_y = np.load(ID[1])
          Y[i, :, :] = np_y

        tau = X.shape[1]          
        v = X.shape[2]

        # frequency and time masking of X values
        warped_frequency_spectrogram = spec_augment_tensorflow.frequency_masking(X, v=v,  frequency_masking_para=8, frequency_mask_num=1)
        warped_frequency_time_spectrogram = spec_augment_tensorflow.time_masking(warped_frequency_spectrogram, tau=tau, time_masking_para=25, time_mask_num=2)

        X = warped_frequency_time_spectrogram

        return X, Y

# %%
# Parametersa
params = {'batch_size': 32, 'shuffle': True}

# Generators
training_generator = DataGenerator(partition['train'], **params)
validation_generator = DataGenerator(partition['validation'], **params)
test_generator = DataGenerator(partition['test'], **params)

# %% [markdown]
# # Define the YOHO network

# %%
def square_difference_loss(y_true, y_pred):
  weight = tf.constant([1.0])

  squared_difference = tf.square(y_true - y_pred)

  ss_True = squared_difference[:, :, 0] * 0 + 1

  # get every 3 value of y_true
  ss_0 = y_true[:, :, 0]
  ss_1 = y_true[:, :, 3]
  ss_2 = y_true[:, :, 6]
  ss_3 = y_true[:, :, 9]
  ss_4 = y_true[:, :, 12]
  ss_5 = y_true[:, :, 15]

  # stack values
  stacked_ss = tf.stack((ss_True, ss_0, ss_0,
                         ss_True, ss_1, ss_1,
                         ss_True, ss_2, ss_2,
                         ss_True, ss_3, ss_3,
                         ss_True, ss_4, ss_4,
                         ss_True, ss_5, ss_5), axis = 2)
  
  squared_difference =  tf.multiply(squared_difference, stacked_ss)

  return tf.reduce_sum(squared_difference, axis=[-1, -2])

# %%
# Creates mel spctrograms for validation fold for training
def create_train_melspectrograms():
  win_length = 2.56
  hop_size = 1.96
  mss_ins = []
  win_ranges_list = []


  for ii, audio in enumerate(fold1_val_files): # why val?
    a, win_ranges = construct_examples(audio, win_len=win_length,hop_len=hop_size)

    mss_in = np.zeros((len(a), 257, 40))

    preds = np.zeros((len(a), 9, 18))

    for i in range(len(a)):
      M = get_log_melspectrogram(a[i])
      mss_in[i, :, :] = M.T
    mss_ins.append(mss_in)
    win_ranges_list.append(win_ranges)
  return mss_ins,win_ranges_list


BASE_MSS_INS, BASE_WIN_RANGE = create_train_melspectrograms()

def mk_preds_YOHO_mel(model, ind, window_range_list=BASE_WIN_RANGE, mss_ins=BASE_MSS_INS, no_of_div = 9, hop_size = 1.96, discard = 0.3, win_length = 2.56, max_event_silence = 0.3, sampling_rate = 44100):
  preds = model.predict(mss_ins[ind])
  events = []

  for i in range(len(preds)):
    p = preds[i, :, :]
    events_curr = []
    win_width = win_length / no_of_div
    for j in range(len(p)):
      for jjj in range(0, 6):
        if p[j][jjj*3] >= 0.5:
          start = win_width * j + win_width * p[j][jjj*3+1] + window_range_list[ind][i][0]
          end = p[j][jjj*3+2] * win_width + start
          events_curr.append([start, end, rev_class_list[jjj]])

    events += events_curr


  class_set = set([c[2] for c in events])
  class_wise_events = {}

  for c in list(class_set):
    class_wise_events[c] = []


  for c in events:
    class_wise_events[c[2]].append(c)
    
  
  all_events = []

  for k in list(class_wise_events.keys()):
    curr_events = class_wise_events[k]
    count = 0

    while count < len(curr_events) - 1:
      if (curr_events[count][1] >= curr_events[count + 1][0]) or (curr_events[count + 1][0] - curr_events[count][1] <= max_event_silence):
        curr_events[count][1] = max(curr_events[count + 1][1], curr_events[count][1])
        del curr_events[count + 1]
      else:
        count += 1

    all_events += curr_events

  for i in range(len(all_events)):
    all_events[i][0] = round(all_events[i][0], 3)
    all_events[i][1] = round(all_events[i][1], 3)

  all_events.sort(key=lambda x: x[0])

  return all_events

# %%
rev_class_list = ['brakes squeaking',
                  'car',
                  'children',
                  'large vehicle',
                  'people speaking',
                  'people walking']

# %%
def frames_to_time(f, sr = 44100.0, hop_size = 441):
  return f * hop_size / sr

def preds_to_se(p, win_start, audio_clip_length = 2.56):
  start_dicts = [-100, -100, -100, -100, -100, -100]
  stop_dicts = [-100, -100, -100, -100, -100, -100]


  start_speech = -100
  start_music = -100
  stop_speech = -100
  stop_music = -100

  audio_events = []

  n_frames = p.shape[0]

  for j in range(p.shape[1]):
    if p[0, j] >= 0.5:
      start_dicts[j] = 0

  for j in range(p.shape[1]):
    for i in range(n_frames - 1):
      if p[i, j] < 0.5 and p[i+1, j] >= 0.5:
        start_dicts[j] = i+1

      elif p[i, j] >= 0.5 and p[i + 1, j] < 0.5:
        stop_dicts[j] = i
        start_time = frames_to_time(start_dicts[j])
        stop_time = frames_to_time(stop_dicts[j])

        audio_events.append([start_time+win_start, stop_time+win_start, rev_class_list[j]])
        start_dicts[j] = -100
        stop_dicts[j] = -100

    if start_dicts[j] != -100:
      start_time = frames_to_time(start_dicts[j])
      stop_time = audio_clip_length
      audio_events.append([start_time+win_start, stop_time+win_start, rev_class_list[j]])
      start_dicts[j] = -100
      stop_dicts[j] = -100

  audio_events.sort(key = lambda x: x[0]) 
  return audio_events

# %%
def extract_eval_labels_2(annotation_path):
  events = convert_annotations_to_events(annotation_path)

  ann = [[float(e[2]), float(e[3]), e[4]] for e in events]
  
  n_label = "/content/eval-files-2/" + os.path.basename(annotation_path)

  with open(n_label, 'w') as fp:
    fp.write('\n'.join('{},{},{}'.format(round(x[0], 5), round(x[1], 5), x[2]) for x in ann))

# %%
shutil.rmtree('/content/eval-files-2/', ignore_errors=True)
os.mkdir("/content/eval-files-2/")

# %%
for audio in fold1_val_files:
  extract_eval_labels_2(audio.replace(".wav", ".ann").replace("audio-mono", "meta"))

# %% [markdown]
# # Train Network

# %%
class KerasFinalCallback(tf.keras.callbacks.Callback):
  def __init__(self):
    super(KerasFinalCallback, self).__init__()
    self.best_f1 = 0.0
    self.best_error = np.inf
    
  def on_train_begin(self, logs=None):
    pass

  def on_train_end(self, logs=None):
    pass

  def on_epoch_end(self, epoch, logs=None):
    if epoch > 1:
      for ii, audio in enumerate(fold1_val_files):
        audio_file_path = audio
        see = mk_preds_YOHO_mel(self.model, ii)
        n_label = n_label = "/content/eval-files-2/" + os.path.basename(audio_file_path).replace(".wav" ,"") + "-se-prediction.ann"

        with open(n_label, 'w') as fp:
          fp.write('\n'.join('{},{},{}'.format(round(x[0], 5), round(x[1], 5), x[2]) for x in see))

      destination = "/content/eval-files-2/"
      test_set = glob.glob(destination + "*[0-9].ann")

      eval_path = "/content/"


      file_list = [
          {
          'reference_file': tt,
          'estimated_file': tt.replace(".ann","-se-prediction.ann")
          }
          for tt in test_set
      ]

      data = []

      # Get used event labels
      all_data = dcase_util.containers.MetaDataContainer()
      for file_pair in file_list:
          reference_event_list = sed_eval.io.load_event_list(
              filename=file_pair['reference_file']
          )
          estimated_event_list = sed_eval.io.load_event_list(
              filename=file_pair['estimated_file']
          )

          data.append({'reference_event_list': reference_event_list,
                      'estimated_event_list': estimated_event_list})

          all_data += reference_event_list

      event_labels = all_data.unique_event_labels

      # Start evaluating

      # Create metrics classes, define parameters
      segment_based_metrics = sed_eval.sound_event.SegmentBasedMetrics(
          event_label_list=event_labels,
          time_resolution=1.0
      )

      event_based_metrics = sed_eval.sound_event.EventBasedMetrics(
          event_label_list=event_labels,
          t_collar=1.0
      )

      # Go through files
      for file_pair in data:
          segment_based_metrics.evaluate(
              reference_event_list=file_pair['reference_event_list'],
              estimated_event_list=file_pair['estimated_event_list']
          )

          event_based_metrics.evaluate(
              reference_event_list=file_pair['reference_event_list'],
              estimated_event_list=file_pair['estimated_event_list']
          )

      # Get only certain metrics
      overall_segment_based_metrics = segment_based_metrics.results_overall_metrics()
      curr_f1 = overall_segment_based_metrics['f_measure']['f_measure']
      curr_error = overall_segment_based_metrics['error_rate']['error_rate']

      if curr_f1 > self.best_f1:
        self.best_f1 = curr_f1
        self.model.save_weights("/content/model-best-f1.h5")

      if curr_error < self.best_error:
        self.best_error = curr_error
        self.model.save_weights("/content/model-best-error.h5")

      print("F-measure: {:.3f} vs {:.3f}".format(curr_f1, self.best_f1))
      print("Error rate: {:.3f} vs {:.3f}".format(curr_error, self.best_error))

# %%
class YOHOBlock:
  def __init__(self, stride, num_filters, index, input):
      X = tf.keras.layers.DepthwiseConv2D(kernel_size=[3,3], strides = stride, depth_multiplier=1, padding='same', use_bias=False,
                                      activation=None, name="layer"+ str(index + 2)+"/depthwise_conv")(input)
      X = tf.keras.layers.BatchNormalization(center=True, scale=False, epsilon=1e-4, name = "layer"+ str(index + 2)+"/depthwise_conv/bn")(X)
      X = tf.keras.layers.ReLU(name="layer"+ str(index + 2)+"/depthwise_conv/relu")(X)
      X = tf.keras.layers.Conv2D(filters =num_filters, kernel_size=[1, 1], strides=1, padding='same', use_bias=False, activation=None,
                                name = "layer"+ str(index + 2)+"/pointwise_conv",
                                kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01))(X)
      X = tf.keras.layers.BatchNormalization(center=True, scale=False, epsilon=1e-4, name = "layer"+ str(index + 2)+"/pointwise_conv/bn")(X)
      self.output = tf.keras.layers.ReLU(name="layer"+ str(index + 2)+"/pointwise_conv/relu")(X)

class Network:
  def __init__(self) -> None:
    self.NETWORK_BLOCK_LAYERS = [
      # (stride, num_filters)
      (1,   64),
      (2,  128),
      (1,  128),
      (2,  256),
      (1,  256),
      (2,  512),
      (1,  512),
      (1,  512),
      (1,  512),
      (1,  512),
      (1,  512),
      (2, 1024),
      (1, 1024),
      (1, 512),
      (1, 256),
      (1, 128),
    ]
    self.m_features = tf.keras.Input(shape=(257, 40), name="mel_input")
    X = self.m_features
    X = tf.keras.layers.Reshape((257, 40, 1))(X)
    X = tf.keras.layers.Conv2D(filters = 32, kernel_size=[3, 3], strides=2, padding='same', use_bias=False,
                              activation=None, name = "layer1/conv",
                                kernel_regularizer=l2(1e-3), bias_regularizer=l2(1e-3))(X)
    X = tf.keras.layers.BatchNormalization(center=True, scale=False, epsilon=1e-4, name = "layer1/bn")(X)
    X = tf.keras.layers.ReLU(name="layer1/relu")(X)

    X = tf.keras.layers.SpatialDropout2D(0.1)(X)
    
    for index in range(len(self.NETWORK_BLOCK_LAYERS)):
      X = YOHOBlock(stride=self.NETWORK_BLOCK_LAYERS[index][0], num_filters=self.NETWORK_BLOCK_LAYERS[index][1], index=index, input=X).output

    _, _, sx, sy = X.shape
    X = tf.keras.layers.Reshape((-1, int(sx * sy)))(X)
    self.pred = tf.keras.layers.Conv1D(18, kernel_size=1, activation="sigmoid")(X)


model_arch = Network()
model = tf.keras.Model(
      name='YOHO', inputs=model_arch.m_features,outputs=[model_arch.pred])

# %%
model.summary()
# Out:
# Model: "YOHO"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mel_input (InputLayer)      [(None, 257, 40)]         0
#
#  reshape_4 (Reshape)         (None, 257, 40, 1)        0
#
#  layer1/conv (Conv2D)        (None, 129, 20, 32)       288
#
#  layer1/bn (BatchNormalizati  (None, 129, 20, 32)      96
#  on)
#
#  layer1/relu (ReLU)          (None, 129, 20, 32)       0
#
#  spatial_dropout2d_2 (Spatia  (None, 129, 20, 32)      0
#  lDropout2D)
#
#  layer2/depthwise_conv (Dept  (None, 129, 20, 32)      288
#  hwiseConv2D)
#
#  layer2/depthwise_conv/bn (B  (None, 129, 20, 32)      96
#  atchNormalization)
#
#  layer2/depthwise_conv/relu   (None, 129, 20, 32)      0
#  (ReLU)
#
#  layer2/pointwise_conv (Conv  (None, 129, 20, 64)      2048
#  2D)
#
#  layer2/pointwise_conv/bn (B  (None, 129, 20, 64)      192
#  atchNormalization)
#
#  layer2/pointwise_conv/relu   (None, 129, 20, 64)      0
#  (ReLU)
#
#  layer3/depthwise_conv (Dept  (None, 65, 10, 64)       576
#  hwiseConv2D)
#
#  layer3/depthwise_conv/bn (B  (None, 65, 10, 64)       192
#  atchNormalization)
#
#  layer3/depthwise_conv/relu   (None, 65, 10, 64)       0
#  (ReLU)
#
#  layer3/pointwise_conv (Conv  (None, 65, 10, 128)      8192
#  2D)
#
#  layer3/pointwise_conv/bn (B  (None, 65, 10, 128)      384
#  atchNormalization)
#
#  layer3/pointwise_conv/relu   (None, 65, 10, 128)      0
#  (ReLU)
#
#  layer4/depthwise_conv (Dept  (None, 65, 10, 128)      1152
#  hwiseConv2D)
#
#  layer4/depthwise_conv/bn (B  (None, 65, 10, 128)      384
#  atchNormalization)
#
#  layer4/depthwise_conv/relu   (None, 65, 10, 128)      0
#  (ReLU)
#
#  layer4/pointwise_conv (Conv  (None, 65, 10, 128)      16384
#  2D)
#
#  layer4/pointwise_conv/bn (B  (None, 65, 10, 128)      384
#  atchNormalization)
#
#  layer4/pointwise_conv/relu   (None, 65, 10, 128)      0
#  (ReLU)
#
#  layer5/depthwise_conv (Dept  (None, 33, 5, 128)       1152
#  hwiseConv2D)
#
#  layer5/depthwise_conv/bn (B  (None, 33, 5, 128)       384
#  atchNormalization)
#
#  layer5/depthwise_conv/relu   (None, 33, 5, 128)       0
#  (ReLU)
#
#  layer5/pointwise_conv (Conv  (None, 33, 5, 256)       32768
#  2D)
#
#  layer5/pointwise_conv/bn (B  (None, 33, 5, 256)       768
#  atchNormalization)
#
#  layer5/pointwise_conv/relu   (None, 33, 5, 256)       0
#  (ReLU)
#
#  layer6/depthwise_conv (Dept  (None, 33, 5, 256)       2304
#  hwiseConv2D)
#
#  layer6/depthwise_conv/bn (B  (None, 33, 5, 256)       768
#  atchNormalization)
#
#  layer6/depthwise_conv/relu   (None, 33, 5, 256)       0
#  (ReLU)
#
#  layer6/pointwise_conv (Conv  (None, 33, 5, 256)       65536
#  2D)
#
#  layer6/pointwise_conv/bn (B  (None, 33, 5, 256)       768
#  atchNormalization)
#
#  layer6/pointwise_conv/relu   (None, 33, 5, 256)       0
#  (ReLU)
#
#  layer7/depthwise_conv (Dept  (None, 17, 3, 256)       2304
#  hwiseConv2D)
#
#  layer7/depthwise_conv/bn (B  (None, 17, 3, 256)       768
#  atchNormalization)
#
#  layer7/depthwise_conv/relu   (None, 17, 3, 256)       0
#  (ReLU)
#
#  layer7/pointwise_conv (Conv  (None, 17, 3, 512)       131072
#  2D)
#
#  layer7/pointwise_conv/bn (B  (None, 17, 3, 512)       1536
#  atchNormalization)
#
#  layer7/pointwise_conv/relu   (None, 17, 3, 512)       0
#  (ReLU)
#
#  layer8/depthwise_conv (Dept  (None, 17, 3, 512)       4608
#  hwiseConv2D)
#
#  layer8/depthwise_conv/bn (B  (None, 17, 3, 512)       1536
#  atchNormalization)
#
#  layer8/depthwise_conv/relu   (None, 17, 3, 512)       0
#  (ReLU)
#
#  layer8/pointwise_conv (Conv  (None, 17, 3, 512)       262144
#  2D)
#
#  layer8/pointwise_conv/bn (B  (None, 17, 3, 512)       1536
#  atchNormalization)
#
#  layer8/pointwise_conv/relu   (None, 17, 3, 512)       0
#  (ReLU)
#
#  layer9/depthwise_conv (Dept  (None, 17, 3, 512)       4608
#  hwiseConv2D)
#
#  layer9/depthwise_conv/bn (B  (None, 17, 3, 512)       1536
#  atchNormalization)
#
#  layer9/depthwise_conv/relu   (None, 17, 3, 512)       0
#  (ReLU)
#
#  layer9/pointwise_conv (Conv  (None, 17, 3, 512)       262144
#  2D)
#
#  layer9/pointwise_conv/bn (B  (None, 17, 3, 512)       1536
#  atchNormalization)
#
#  layer9/pointwise_conv/relu   (None, 17, 3, 512)       0
#  (ReLU)
#
#  layer10/depthwise_conv (Dep  (None, 17, 3, 512)       4608
#  thwiseConv2D)
#
#  layer10/depthwise_conv/bn (  (None, 17, 3, 512)       1536
#  BatchNormalization)
#
#  layer10/depthwise_conv/relu  (None, 17, 3, 512)       0
#   (ReLU)
#
#  layer10/pointwise_conv (Con  (None, 17, 3, 512)       262144
#  v2D)
#
#  layer10/pointwise_conv/bn (  (None, 17, 3, 512)       1536
#  BatchNormalization)
#
#  layer10/pointwise_conv/relu  (None, 17, 3, 512)       0
#   (ReLU)
#
#  layer11/depthwise_conv (Dep  (None, 17, 3, 512)       4608
#  thwiseConv2D)
#
#  layer11/depthwise_conv/bn (  (None, 17, 3, 512)       1536
#  BatchNormalization)
#
#  layer11/depthwise_conv/relu  (None, 17, 3, 512)       0
#   (ReLU)
#
#  layer11/pointwise_conv (Con  (None, 17, 3, 512)       262144
#  v2D)
#
#  layer11/pointwise_conv/bn (  (None, 17, 3, 512)       1536
#  BatchNormalization)
#
#  layer11/pointwise_conv/relu  (None, 17, 3, 512)       0
#   (ReLU)
#
#  layer12/depthwise_conv (Dep  (None, 17, 3, 512)       4608
#  thwiseConv2D)
#
#  layer12/depthwise_conv/bn (  (None, 17, 3, 512)       1536
#  BatchNormalization)
#
#  layer12/depthwise_conv/relu  (None, 17, 3, 512)       0
#   (ReLU)
#
#  layer12/pointwise_conv (Con  (None, 17, 3, 512)       262144
#  v2D)
#
#  layer12/pointwise_conv/bn (  (None, 17, 3, 512)       1536
#  BatchNormalization)
#
#  layer12/pointwise_conv/relu  (None, 17, 3, 512)       0
#   (ReLU)
#
#  layer13/depthwise_conv (Dep  (None, 9, 2, 512)        4608
#  thwiseConv2D)
#
#  layer13/depthwise_conv/bn (  (None, 9, 2, 512)        1536
#  BatchNormalization)
#
#  layer13/depthwise_conv/relu  (None, 9, 2, 512)        0
#   (ReLU)
#
#  layer13/pointwise_conv (Con  (None, 9, 2, 1024)       524288
#  v2D)
#
#  layer13/pointwise_conv/bn (  (None, 9, 2, 1024)       3072
#  BatchNormalization)
#
#  layer13/pointwise_conv/relu  (None, 9, 2, 1024)       0
#   (ReLU)
#
#  layer14/depthwise_conv (Dep  (None, 9, 2, 1024)       9216
#  thwiseConv2D)
#
#  layer14/depthwise_conv/bn (  (None, 9, 2, 1024)       3072
#  BatchNormalization)
#
#  layer14/depthwise_conv/relu  (None, 9, 2, 1024)       0
#   (ReLU)
#
#  layer14/pointwise_conv (Con  (None, 9, 2, 1024)       1048576
#  v2D)
#
#  layer14/pointwise_conv/bn (  (None, 9, 2, 1024)       3072
#  BatchNormalization)
#
#  layer14/pointwise_conv/relu  (None, 9, 2, 1024)       0
#   (ReLU)
#
#  layer15/depthwise_conv (Dep  (None, 9, 2, 1024)       9216
#  thwiseConv2D)
#
#  layer15/depthwise_conv/bn (  (None, 9, 2, 1024)       3072
#  BatchNormalization)
#
#  layer15/depthwise_conv/relu  (None, 9, 2, 1024)       0
#   (ReLU)
#
#  layer15/pointwise_conv (Con  (None, 9, 2, 512)        524288
#  v2D)
#
#  layer15/pointwise_conv/bn (  (None, 9, 2, 512)        1536
#  BatchNormalization)
#
#  layer15/pointwise_conv/relu  (None, 9, 2, 512)        0
#   (ReLU)
#
#  layer16/depthwise_conv (Dep  (None, 9, 2, 512)        4608
#  thwiseConv2D)
#
#  layer16/depthwise_conv/bn (  (None, 9, 2, 512)        1536
#  BatchNormalization)
#
#  layer16/depthwise_conv/relu  (None, 9, 2, 512)        0
#   (ReLU)
#
#  layer16/pointwise_conv (Con  (None, 9, 2, 256)        131072
#  v2D)
#
#  layer16/pointwise_conv/bn (  (None, 9, 2, 256)        768
#  BatchNormalization)
#
#  layer16/pointwise_conv/relu  (None, 9, 2, 256)        0
#   (ReLU)
#
#  layer17/depthwise_conv (Dep  (None, 9, 2, 256)        2304
#  thwiseConv2D)
#
#  layer17/depthwise_conv/bn (  (None, 9, 2, 256)        768
#  BatchNormalization)
#
#  layer17/depthwise_conv/relu  (None, 9, 2, 256)        0
#   (ReLU)
#
#  layer17/pointwise_conv (Con  (None, 9, 2, 128)        32768
#  v2D)
#
#  layer17/pointwise_conv/bn (  (None, 9, 2, 128)        384
#  BatchNormalization)
#
#  layer17/pointwise_conv/relu  (None, 9, 2, 128)        0
#   (ReLU)
#
#  reshape_5 (Reshape)         (None, 9, 256)            0
#
#  conv1d_2 (Conv1D)           (None, 9, 18)             4626
#
# =================================================================
# Total params: 3,934,290
# Trainable params: 3,907,026
# Non-trainable params: 27,264
# _________________________________________________________________

# %%
learning_rate = 1e-3
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), 
              loss=square_difference_loss)

# %%
model.fit(training_generator, validation_data=validation_generator, epochs=1000, callbacks=[KerasFinalCallback()], verbose=1)
# Out:
# Epoch 1/1000
# 67/67 [==============================] - 164s 1s/step - loss: 70.5396 - accuracy: 0.0041 - val_loss: 70.8024 - val_accuracy: 0.0000e+00
# Epoch 2/1000
# 67/67 [==============================] - 80s 1s/step - loss: 59.4765 - accuracy: 0.0000e+00 - val_loss: 59.3219 - val_accuracy: 0.0000e+00
# Epoch 3/1000
# 4/4 [==============================] - 1s 180ms/step
# 4/4 [==============================] - 1s 148ms/step
# 4/4 [==============================] - 1s 179ms/step
# 4/4 [==============================] - 1s 232ms/step
# 3/3 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 152ms/step
# F-measure: nan vs 0.000
# Error rate: 1.000 vs 1.000
# 67/67 [==============================] - 87s 1s/step - loss: 49.4950 - accuracy: 0.0000e+00 - val_loss: 50.0143 - val_accuracy: 0.0000e+00
# Epoch 4/1000
# 4/4 [==============================] - 1s 178ms/step
# 4/4 [==============================] - 1s 151ms/step
# 4/4 [==============================] - 1s 182ms/step
# 4/4 [==============================] - 1s 167ms/step
# 3/3 [==============================] - 1s 179ms/step
# 4/4 [==============================] - 1s 152ms/step
# F-measure: nan vs 0.000
# Error rate: 1.000 vs 1.000
# 67/67 [==============================] - 88s 1s/step - loss: 41.6264 - accuracy: 0.0000e+00 - val_loss: 42.8119 - val_accuracy: 0.0000e+00
# Epoch 5/1000
# 4/4 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 151ms/step
# 4/4 [==============================] - 1s 174ms/step
# 4/4 [==============================] - 1s 165ms/step
# 3/3 [==============================] - 1s 185ms/step
# 4/4 [==============================] - 1s 150ms/step
# F-measure: nan vs 0.000
# Error rate: 1.000 vs 1.000
# 67/67 [==============================] - 87s 1s/step - loss: 35.7793 - accuracy: 0.0000e+00 - val_loss: 37.3758 - val_accuracy: 0.0000e+00
# Epoch 6/1000
# 4/4 [==============================] - 1s 175ms/step
# 4/4 [==============================] - 1s 149ms/step
# 4/4 [==============================] - 1s 179ms/step
# 4/4 [==============================] - 1s 167ms/step
# 3/3 [==============================] - 1s 190ms/step
# 4/4 [==============================] - 1s 156ms/step
# F-measure: nan vs 0.000
# Error rate: 1.000 vs 1.000
# 67/67 [==============================] - 87s 1s/step - loss: 31.3174 - accuracy: 0.0000e+00 - val_loss: 33.0568 - val_accuracy: 0.0000e+00
# Epoch 7/1000
# 4/4 [==============================] - 1s 175ms/step
# 4/4 [==============================] - 1s 151ms/step
# 4/4 [==============================] - 1s 182ms/step
# 4/4 [==============================] - 1s 168ms/step
# 3/3 [==============================] - 1s 260ms/step
# 4/4 [==============================] - 1s 212ms/step
# F-measure: nan vs 0.000
# Error rate: 1.000 vs 1.000
# 67/67 [==============================] - 89s 1s/step - loss: 27.8255 - accuracy: 0.0000e+00 - val_loss: 29.4420 - val_accuracy: 0.0000e+00
# Epoch 8/1000
# 4/4 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 144ms/step
# 4/4 [==============================] - 1s 178ms/step
# 4/4 [==============================] - 1s 164ms/step
# 3/3 [==============================] - 1s 266ms/step
# 4/4 [==============================] - 1s 209ms/step
# F-measure: nan vs 0.000
# Error rate: 1.000 vs 1.000
# 67/67 [==============================] - 88s 1s/step - loss: 25.1057 - accuracy: 0.0000e+00 - val_loss: 26.2179 - val_accuracy: 0.0000e+00
# Epoch 9/1000
# 4/4 [==============================] - 1s 180ms/step
# 4/4 [==============================] - 1s 148ms/step
# 4/4 [==============================] - 1s 178ms/step
# 4/4 [==============================] - 1s 236ms/step
# 3/3 [==============================] - 1s 213ms/step
# 4/4 [==============================] - 1s 150ms/step
# F-measure: nan vs 0.000
# Error rate: 1.000 vs 1.000
# 67/67 [==============================] - 89s 1s/step - loss: 22.7148 - accuracy: 0.0000e+00 - val_loss: 22.9236 - val_accuracy: 0.0000e+00
# Epoch 10/1000
# 4/4 [==============================] - 1s 187ms/step
# 4/4 [==============================] - 1s 158ms/step
# 4/4 [==============================] - 1s 207ms/step
# 4/4 [==============================] - 1s 229ms/step
# 3/3 [==============================] - 1s 184ms/step
# 4/4 [==============================] - 1s 149ms/step
# F-measure: nan vs 0.000
# Error rate: 1.000 vs 1.000
# 67/67 [==============================] - 88s 1s/step - loss: 20.8276 - accuracy: 0.0000e+00 - val_loss: 20.7102 - val_accuracy: 0.0000e+00
# Epoch 11/1000
# 4/4 [==============================] - 1s 178ms/step
# 4/4 [==============================] - 1s 147ms/step
# 4/4 [==============================] - 1s 254ms/step
# 4/4 [==============================] - 1s 191ms/step
# 3/3 [==============================] - 1s 182ms/step
# 4/4 [==============================] - 1s 148ms/step
# F-measure: 0.011 vs 0.011
# Error rate: 0.994 vs 0.994
# 67/67 [==============================] - 89s 1s/step - loss: 19.3578 - accuracy: 0.0000e+00 - val_loss: 18.6155 - val_accuracy: 0.0000e+00
# Epoch 12/1000
# 4/4 [==============================] - 1s 181ms/step
# 4/4 [==============================] - 1s 214ms/step
# 4/4 [==============================] - 1s 252ms/step
# 4/4 [==============================] - 1s 167ms/step
# 3/3 [==============================] - 1s 179ms/step
# 4/4 [==============================] - 1s 152ms/step
# F-measure: 0.439 vs 0.439
# Error rate: 0.755 vs 0.755
# 67/67 [==============================] - 88s 1s/step - loss: 17.8393 - accuracy: 0.0000e+00 - val_loss: 17.2456 - val_accuracy: 0.0000e+00
# Epoch 13/1000
# 4/4 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 151ms/step
# 4/4 [==============================] - 1s 181ms/step
# 4/4 [==============================] - 1s 232ms/step
# 3/3 [==============================] - 1s 260ms/step
# 4/4 [==============================] - 1s 147ms/step
# F-measure: 0.345 vs 0.439
# Error rate: 0.847 vs 0.755
# 67/67 [==============================] - 87s 1s/step - loss: 16.7020 - accuracy: 0.0000e+00 - val_loss: 16.0746 - val_accuracy: 0.0000e+00
# Epoch 14/1000
# 4/4 [==============================] - 1s 182ms/step
# 4/4 [==============================] - 1s 199ms/step
# 4/4 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 167ms/step
# 3/3 [==============================] - 1s 184ms/step
# 4/4 [==============================] - 1s 151ms/step
# F-measure: 0.441 vs 0.441
# Error rate: 0.763 vs 0.755
# 67/67 [==============================] - 86s 1s/step - loss: 15.5652 - accuracy: 0.0000e+00 - val_loss: 14.8981 - val_accuracy: 0.0000e+00
# Epoch 15/1000
# 4/4 [==============================] - 1s 186ms/step
# 4/4 [==============================] - 1s 154ms/step
# 4/4 [==============================] - 1s 182ms/step
# 4/4 [==============================] - 1s 165ms/step
# 3/3 [==============================] - 1s 254ms/step
# 4/4 [==============================] - 1s 223ms/step
# F-measure: 0.407 vs 0.441
# Error rate: 0.835 vs 0.755
# 67/67 [==============================] - 88s 1s/step - loss: 14.6643 - accuracy: 0.0000e+00 - val_loss: 14.6723 - val_accuracy: 0.0000e+00
# Epoch 16/1000
# 4/4 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 149ms/step
# 4/4 [==============================] - 1s 251ms/step
# 4/4 [==============================] - 1s 174ms/step
# 3/3 [==============================] - 1s 188ms/step
# 4/4 [==============================] - 1s 148ms/step
# F-measure: 0.397 vs 0.441
# Error rate: 0.794 vs 0.755
# 67/67 [==============================] - 88s 1s/step - loss: 13.8107 - accuracy: 0.0000e+00 - val_loss: 13.3810 - val_accuracy: 0.0000e+00
# Epoch 17/1000
# 4/4 [==============================] - 1s 180ms/step
# 4/4 [==============================] - 1s 152ms/step
# 4/4 [==============================] - 1s 244ms/step
# 4/4 [==============================] - 1s 161ms/step
# 3/3 [==============================] - 1s 183ms/step
# 4/4 [==============================] - 1s 150ms/step
# F-measure: 0.288 vs 0.441
# Error rate: 1.678 vs 0.755
# 67/67 [==============================] - 87s 1s/step - loss: 13.1508 - accuracy: 0.0000e+00 - val_loss: 15.0218 - val_accuracy: 0.0000e+00
# Epoch 18/1000
# 4/4 [==============================] - 1s 172ms/step
# 4/4 [==============================] - 1s 152ms/step
# 4/4 [==============================] - 1s 175ms/step
# 4/4 [==============================] - 1s 167ms/step
# 3/3 [==============================] - 1s 181ms/step
# 4/4 [==============================] - 1s 152ms/step
# F-measure: 0.470 vs 0.470
# Error rate: 0.772 vs 0.755
# 67/67 [==============================] - 87s 1s/step - loss: 12.6863 - accuracy: 0.0000e+00 - val_loss: 12.2929 - val_accuracy: 0.0000e+00
# Epoch 19/1000
# 4/4 [==============================] - 1s 178ms/step
# 4/4 [==============================] - 1s 149ms/step
# 4/4 [==============================] - 1s 173ms/step
# 4/4 [==============================] - 1s 165ms/step
# 3/3 [==============================] - 1s 177ms/step
# 4/4 [==============================] - 1s 150ms/step
# F-measure: 0.423 vs 0.470
# Error rate: 0.931 vs 0.755
# 67/67 [==============================] - 86s 1s/step - loss: 12.1130 - accuracy: 0.0000e+00 - val_loss: 12.3705 - val_accuracy: 0.0000e+00
# Epoch 20/1000
# 4/4 [==============================] - 1s 173ms/step
# 4/4 [==============================] - 1s 145ms/step
# 4/4 [==============================] - 1s 185ms/step
# 4/4 [==============================] - 1s 164ms/step
# 3/3 [==============================] - 1s 173ms/step
# 4/4 [==============================] - 1s 146ms/step
# F-measure: 0.405 vs 0.470
# Error rate: 0.987 vs 0.755
# 67/67 [==============================] - 87s 1s/step - loss: 11.6088 - accuracy: 0.0000e+00 - val_loss: 12.6912 - val_accuracy: 0.0000e+00
# Epoch 21/1000
# 4/4 [==============================] - 1s 174ms/step
# 4/4 [==============================] - 1s 150ms/step
# 4/4 [==============================] - 1s 180ms/step
# 4/4 [==============================] - 1s 193ms/step
# 3/3 [==============================] - 1s 257ms/step
# 4/4 [==============================] - 1s 150ms/step
# F-measure: 0.454 vs 0.470
# Error rate: 1.133 vs 0.755
# 67/67 [==============================] - 88s 1s/step - loss: 11.1410 - accuracy: 0.0000e+00 - val_loss: 12.8970 - val_accuracy: 0.0000e+00
# Epoch 22/1000
# 4/4 [==============================] - 1s 178ms/step
# 4/4 [==============================] - 1s 186ms/step
# 4/4 [==============================] - 1s 227ms/step
# 4/4 [==============================] - 1s 163ms/step
# 3/3 [==============================] - 1s 178ms/step
# 4/4 [==============================] - 1s 150ms/step
# F-measure: 0.445 vs 0.470
# Error rate: 0.865 vs 0.755
# 67/67 [==============================] - 85s 1s/step - loss: 10.7991 - accuracy: 0.0000e+00 - val_loss: 11.8720 - val_accuracy: 0.0023
# Epoch 23/1000
# 4/4 [==============================] - 1s 171ms/step
# 4/4 [==============================] - 1s 149ms/step
# 4/4 [==============================] - 1s 177ms/step
# 4/4 [==============================] - 1s 160ms/step
# 3/3 [==============================] - 1s 180ms/step
# 4/4 [==============================] - 1s 148ms/step
# F-measure: 0.426 vs 0.470
# Error rate: 0.896 vs 0.755
# 67/67 [==============================] - 88s 1s/step - loss: 10.3387 - accuracy: 0.0000e+00 - val_loss: 10.0685 - val_accuracy: 0.0000e+00
# Epoch 24/1000
# 4/4 [==============================] - 1s 178ms/step
# 4/4 [==============================] - 1s 147ms/step
# 4/4 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 161ms/step
# 3/3 [==============================] - 1s 175ms/step
# 4/4 [==============================] - 1s 146ms/step
# F-measure: 0.521 vs 0.521
# Error rate: 0.732 vs 0.732
# 67/67 [==============================] - 87s 1s/step - loss: 10.0971 - accuracy: 0.0000e+00 - val_loss: 9.7837 - val_accuracy: 0.0000e+00
# Epoch 25/1000
# 4/4 [==============================] - 1s 180ms/step
# 4/4 [==============================] - 1s 150ms/step
# 4/4 [==============================] - 1s 180ms/step
# 4/4 [==============================] - 1s 162ms/step
# 3/3 [==============================] - 1s 186ms/step
# 4/4 [==============================] - 1s 150ms/step
# F-measure: 0.402 vs 0.521
# Error rate: 1.363 vs 0.732
# 67/67 [==============================] - 87s 1s/step - loss: 9.9338 - accuracy: 0.0000e+00 - val_loss: 12.6484 - val_accuracy: 0.0000e+00
# Epoch 26/1000
# 4/4 [==============================] - 1s 174ms/step
# 4/4 [==============================] - 1s 155ms/step
# 4/4 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 165ms/step
# 3/3 [==============================] - 1s 178ms/step
# 4/4 [==============================] - 1s 152ms/step
# F-measure: 0.498 vs 0.521
# Error rate: 0.772 vs 0.732
# 67/67 [==============================] - 87s 1s/step - loss: 9.7097 - accuracy: 0.0000e+00 - val_loss: 9.6122 - val_accuracy: 0.0000e+00
# Epoch 27/1000
# 4/4 [==============================] - 1s 179ms/step
# 4/4 [==============================] - 1s 153ms/step
# 4/4 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 229ms/step
# 3/3 [==============================] - 1s 220ms/step
# 4/4 [==============================] - 1s 151ms/step
# F-measure: 0.387 vs 0.521
# Error rate: 0.956 vs 0.732
# 67/67 [==============================] - 89s 1s/step - loss: 9.3007 - accuracy: 0.0000e+00 - val_loss: 9.6864 - val_accuracy: 0.0000e+00
# Epoch 28/1000
# 4/4 [==============================] - 1s 178ms/step
# 4/4 [==============================] - 1s 153ms/step
# 4/4 [==============================] - 1s 215ms/step
# 4/4 [==============================] - 1s 222ms/step
# 3/3 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 150ms/step
# F-measure: 0.490 vs 0.521
# Error rate: 1.008 vs 0.732
# 67/67 [==============================] - 88s 1s/step - loss: 9.2042 - accuracy: 0.0000e+00 - val_loss: 9.8826 - val_accuracy: 0.0000e+00
# Epoch 29/1000
# 4/4 [==============================] - 1s 180ms/step
# 4/4 [==============================] - 1s 209ms/step
# 4/4 [==============================] - 1s 179ms/step
# 4/4 [==============================] - 1s 157ms/step
# 3/3 [==============================] - 1s 175ms/step
# 4/4 [==============================] - 1s 148ms/step
# F-measure: 0.420 vs 0.521
# Error rate: 0.948 vs 0.732
# 67/67 [==============================] - 87s 1s/step - loss: 8.9565 - accuracy: 0.0000e+00 - val_loss: 9.5535 - val_accuracy: 0.0000e+00
# Epoch 30/1000
# 4/4 [==============================] - 1s 213ms/step
# 4/4 [==============================] - 1s 146ms/step
# 4/4 [==============================] - 1s 178ms/step
# 4/4 [==============================] - 1s 164ms/step
# 3/3 [==============================] - 1s 179ms/step
# 4/4 [==============================] - 1s 150ms/step
# F-measure: 0.418 vs 0.521
# Error rate: 1.069 vs 0.732
# 67/67 [==============================] - 87s 1s/step - loss: 8.7693 - accuracy: 0.0000e+00 - val_loss: 11.3232 - val_accuracy: 0.0000e+00
# Epoch 31/1000
# 4/4 [==============================] - 1s 181ms/step
# 4/4 [==============================] - 1s 150ms/step
# 4/4 [==============================] - 1s 183ms/step
# 4/4 [==============================] - 1s 165ms/step
# 3/3 [==============================] - 1s 178ms/step
# 4/4 [==============================] - 1s 146ms/step
# F-measure: 0.495 vs 0.521
# Error rate: 0.794 vs 0.732
# 67/67 [==============================] - 86s 1s/step - loss: 8.5634 - accuracy: 0.0000e+00 - val_loss: 8.9834 - val_accuracy: 0.0000e+00
# Epoch 32/1000
# 4/4 [==============================] - 1s 173ms/step
# 4/4 [==============================] - 1s 147ms/step
# 4/4 [==============================] - 1s 173ms/step
# 4/4 [==============================] - 1s 156ms/step
# 3/3 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 141ms/step
# F-measure: 0.467 vs 0.521
# Error rate: 0.957 vs 0.732
# 67/67 [==============================] - 86s 1s/step - loss: 8.3708 - accuracy: 0.0000e+00 - val_loss: 9.1468 - val_accuracy: 0.0000e+00
# Epoch 33/1000
# 4/4 [==============================] - 1s 172ms/step
# 4/4 [==============================] - 1s 145ms/step
# 4/4 [==============================] - 1s 188ms/step
# 4/4 [==============================] - 1s 229ms/step
# 3/3 [==============================] - 1s 171ms/step
# 4/4 [==============================] - 1s 145ms/step
# F-measure: 0.438 vs 0.521
# Error rate: 0.820 vs 0.732
# 67/67 [==============================] - 85s 1s/step - loss: 8.4077 - accuracy: 0.0000e+00 - val_loss: 9.0738 - val_accuracy: 0.0000e+00
# Epoch 34/1000
# 4/4 [==============================] - 1s 167ms/step
# 4/4 [==============================] - 1s 147ms/step
# 4/4 [==============================] - 1s 171ms/step
# 4/4 [==============================] - 1s 157ms/step
# 3/3 [==============================] - 1s 167ms/step
# 4/4 [==============================] - 1s 147ms/step
# F-measure: 0.445 vs 0.521
# Error rate: 1.014 vs 0.732
# 67/67 [==============================] - 84s 1s/step - loss: 8.0787 - accuracy: 0.0000e+00 - val_loss: 8.7537 - val_accuracy: 0.0000e+00
# Epoch 35/1000
# 4/4 [==============================] - 1s 199ms/step
# 4/4 [==============================] - 1s 149ms/step
# 4/4 [==============================] - 1s 173ms/step
# 4/4 [==============================] - 1s 162ms/step
# 3/3 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 144ms/step
# F-measure: 0.487 vs 0.521
# Error rate: 0.727 vs 0.727
# 67/67 [==============================] - 85s 1s/step - loss: 8.1006 - accuracy: 0.0000e+00 - val_loss: 7.9939 - val_accuracy: 0.0000e+00
# Epoch 36/1000
# 4/4 [==============================] - 1s 170ms/step
# 4/4 [==============================] - 1s 151ms/step
# 4/4 [==============================] - 1s 170ms/step
# 4/4 [==============================] - 1s 155ms/step
# 3/3 [==============================] - 1s 174ms/step
# 4/4 [==============================] - 1s 157ms/step
# F-measure: 0.468 vs 0.521
# Error rate: 0.773 vs 0.727
# 67/67 [==============================] - 86s 1s/step - loss: 8.0318 - accuracy: 0.0000e+00 - val_loss: 8.1116 - val_accuracy: 0.0000e+00
# Epoch 37/1000
# 4/4 [==============================] - 1s 170ms/step
# 4/4 [==============================] - 1s 141ms/step
# 4/4 [==============================] - 1s 167ms/step
# 4/4 [==============================] - 1s 157ms/step
# 3/3 [==============================] - 1s 172ms/step
# 4/4 [==============================] - 1s 147ms/step
# F-measure: 0.493 vs 0.521
# Error rate: 0.775 vs 0.727
# 67/67 [==============================] - 86s 1s/step - loss: 7.8019 - accuracy: 0.0000e+00 - val_loss: 7.9215 - val_accuracy: 0.0000e+00
# Epoch 38/1000
# 4/4 [==============================] - 1s 172ms/step
# 4/4 [==============================] - 1s 148ms/step
# 4/4 [==============================] - 1s 175ms/step
# 4/4 [==============================] - 1s 163ms/step
# 3/3 [==============================] - 1s 208ms/step
# 4/4 [==============================] - 1s 215ms/step
# F-measure: 0.509 vs 0.521
# Error rate: 0.787 vs 0.727
# 67/67 [==============================] - 85s 1s/step - loss: 7.6616 - accuracy: 0.0000e+00 - val_loss: 8.2691 - val_accuracy: 0.0000e+00
# Epoch 39/1000
# 4/4 [==============================] - 1s 177ms/step
# 4/4 [==============================] - 1s 148ms/step
# 4/4 [==============================] - 1s 170ms/step
# 4/4 [==============================] - 1s 163ms/step
# 3/3 [==============================] - 1s 178ms/step
# 4/4 [==============================] - 1s 145ms/step
# F-measure: 0.476 vs 0.521
# Error rate: 1.035 vs 0.727
# 67/67 [==============================] - 85s 1s/step - loss: 7.7473 - accuracy: 0.0000e+00 - val_loss: 8.7491 - val_accuracy: 0.0000e+00
# Epoch 40/1000
# 4/4 [==============================] - 1s 177ms/step
# 4/4 [==============================] - 1s 144ms/step
# 4/4 [==============================] - 1s 181ms/step
# 4/4 [==============================] - 1s 230ms/step
# 3/3 [==============================] - 1s 249ms/step
# 4/4 [==============================] - 1s 147ms/step
# F-measure: 0.468 vs 0.521
# Error rate: 1.022 vs 0.727
# 67/67 [==============================] - 84s 1s/step - loss: 7.8017 - accuracy: 0.0000e+00 - val_loss: 8.8350 - val_accuracy: 0.0000e+00
# Epoch 41/1000
# 4/4 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 146ms/step
# 4/4 [==============================] - 1s 173ms/step
# 4/4 [==============================] - 1s 156ms/step
# 3/3 [==============================] - 1s 173ms/step
# 4/4 [==============================] - 1s 145ms/step
# F-measure: 0.510 vs 0.521
# Error rate: 0.803 vs 0.727
# 67/67 [==============================] - 85s 1s/step - loss: 7.5910 - accuracy: 0.0000e+00 - val_loss: 7.4129 - val_accuracy: 0.0000e+00
# Epoch 42/1000
# 4/4 [==============================] - 1s 173ms/step
# 4/4 [==============================] - 1s 147ms/step
# 4/4 [==============================] - 1s 172ms/step
# 4/4 [==============================] - 1s 159ms/step
# 3/3 [==============================] - 1s 193ms/step
# 4/4 [==============================] - 1s 151ms/step
# F-measure: 0.430 vs 0.521
# Error rate: 0.911 vs 0.727
# 67/67 [==============================] - 87s 1s/step - loss: 7.4313 - accuracy: 0.0000e+00 - val_loss: 8.6497 - val_accuracy: 0.0000e+00
# Epoch 43/1000
# 4/4 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 149ms/step
# 4/4 [==============================] - 1s 175ms/step
# 4/4 [==============================] - 1s 166ms/step
# 3/3 [==============================] - 1s 258ms/step
# 4/4 [==============================] - 1s 151ms/step
# F-measure: 0.503 vs 0.521
# Error rate: 0.695 vs 0.695
# 67/67 [==============================] - 86s 1s/step - loss: 7.1580 - accuracy: 0.0000e+00 - val_loss: 7.2876 - val_accuracy: 0.0000e+00
# Epoch 44/1000
# 4/4 [==============================] - 1s 173ms/step
# 4/4 [==============================] - 1s 146ms/step
# 4/4 [==============================] - 1s 177ms/step
# 4/4 [==============================] - 1s 157ms/step
# 3/3 [==============================] - 1s 170ms/step
# 4/4 [==============================] - 1s 145ms/step
# F-measure: 0.425 vs 0.521
# Error rate: 1.122 vs 0.695
# 67/67 [==============================] - 83s 1s/step - loss: 7.1998 - accuracy: 0.0000e+00 - val_loss: 9.6297 - val_accuracy: 0.0000e+00
# Epoch 45/1000
# 4/4 [==============================] - 1s 170ms/step
# 4/4 [==============================] - 1s 146ms/step
# 4/4 [==============================] - 1s 228ms/step
# 4/4 [==============================] - 1s 215ms/step
# 3/3 [==============================] - 1s 172ms/step
# 4/4 [==============================] - 1s 142ms/step
# F-measure: 0.514 vs 0.521
# Error rate: 0.803 vs 0.695
# 67/67 [==============================] - 83s 1s/step - loss: 7.1309 - accuracy: 0.0000e+00 - val_loss: 8.5103 - val_accuracy: 0.0000e+00
# Epoch 46/1000
# 4/4 [==============================] - 1s 173ms/step
# 4/4 [==============================] - 1s 150ms/step
# 4/4 [==============================] - 1s 174ms/step
# 4/4 [==============================] - 1s 160ms/step
# 3/3 [==============================] - 1s 181ms/step
# 4/4 [==============================] - 1s 155ms/step
# F-measure: 0.562 vs 0.562
# Error rate: 0.716 vs 0.695
# 67/67 [==============================] - 84s 1s/step - loss: 6.9117 - accuracy: 0.0000e+00 - val_loss: 7.6772 - val_accuracy: 0.0000e+00
# Epoch 47/1000
# 4/4 [==============================] - 1s 172ms/step
# 4/4 [==============================] - 1s 187ms/step
# 4/4 [==============================] - 1s 172ms/step
# 4/4 [==============================] - 1s 159ms/step
# 3/3 [==============================] - 1s 168ms/step
# 4/4 [==============================] - 1s 146ms/step
# F-measure: 0.428 vs 0.562
# Error rate: 1.206 vs 0.695
# 67/67 [==============================] - 86s 1s/step - loss: 6.9795 - accuracy: 0.0000e+00 - val_loss: 9.0795 - val_accuracy: 0.0000e+00
# Epoch 48/1000
# 4/4 [==============================] - 1s 174ms/step
# 4/4 [==============================] - 1s 149ms/step
# 4/4 [==============================] - 1s 171ms/step
# 4/4 [==============================] - 1s 167ms/step
# 3/3 [==============================] - 1s 171ms/step
# 4/4 [==============================] - 1s 149ms/step
# F-measure: 0.436 vs 0.562
# Error rate: 0.903 vs 0.695
# 67/67 [==============================] - 86s 1s/step - loss: 6.9263 - accuracy: 0.0000e+00 - val_loss: 7.7221 - val_accuracy: 0.0000e+00
# Epoch 49/1000
# 4/4 [==============================] - 1s 174ms/step
# 4/4 [==============================] - 1s 146ms/step
# 4/4 [==============================] - 1s 172ms/step
# 4/4 [==============================] - 1s 163ms/step
# 3/3 [==============================] - 1s 174ms/step
# 4/4 [==============================] - 1s 146ms/step
# F-measure: 0.483 vs 0.562
# Error rate: 0.888 vs 0.695
# 67/67 [==============================] - 86s 1s/step - loss: 6.8408 - accuracy: 0.0000e+00 - val_loss: 8.5908 - val_accuracy: 0.0000e+00
# Epoch 50/1000
# 4/4 [==============================] - 1s 174ms/step
# 4/4 [==============================] - 1s 148ms/step
# 4/4 [==============================] - 1s 171ms/step
# 4/4 [==============================] - 1s 161ms/step
# 3/3 [==============================] - 1s 174ms/step
# 4/4 [==============================] - 1s 170ms/step
# F-measure: 0.424 vs 0.562
# Error rate: 1.065 vs 0.695
# 67/67 [==============================] - 85s 1s/step - loss: 6.7413 - accuracy: 0.0000e+00 - val_loss: 8.7378 - val_accuracy: 0.0000e+00
# Epoch 51/1000
# 4/4 [==============================] - 1s 178ms/step
# 4/4 [==============================] - 1s 156ms/step
# 4/4 [==============================] - 1s 206ms/step
# 4/4 [==============================] - 1s 181ms/step
# 3/3 [==============================] - 1s 180ms/step
# 4/4 [==============================] - 1s 157ms/step
# F-measure: 0.491 vs 0.562
# Error rate: 0.875 vs 0.695
# 67/67 [==============================] - 85s 1s/step - loss: 6.7160 - accuracy: 0.0000e+00 - val_loss: 7.8947 - val_accuracy: 0.0000e+00
# Epoch 52/1000
# 4/4 [==============================] - 1s 179ms/step
# 4/4 [==============================] - 1s 156ms/step
# 4/4 [==============================] - 1s 182ms/step
# 4/4 [==============================] - 1s 168ms/step
# 3/3 [==============================] - 1s 252ms/step
# 4/4 [==============================] - 1s 216ms/step
# F-measure: 0.425 vs 0.562
# Error rate: 1.139 vs 0.695
# 67/67 [==============================] - 85s 1s/step - loss: 6.6567 - accuracy: 0.0000e+00 - val_loss: 9.0880 - val_accuracy: 0.0000e+00
# Epoch 53/1000
# 4/4 [==============================] - 1s 179ms/step
# 4/4 [==============================] - 1s 152ms/step
# 4/4 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 169ms/step
# 3/3 [==============================] - 1s 178ms/step
# 4/4 [==============================] - 1s 151ms/step
# F-measure: 0.455 vs 0.562
# Error rate: 0.979 vs 0.695
# 67/67 [==============================] - 85s 1s/step - loss: 6.6627 - accuracy: 0.0000e+00 - val_loss: 7.5230 - val_accuracy: 0.0000e+00
# Epoch 54/1000
# 4/4 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 152ms/step
# 4/4 [==============================] - 1s 257ms/step
# 4/4 [==============================] - 1s 159ms/step
# 3/3 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 149ms/step
# F-measure: 0.320 vs 0.562
# Error rate: 0.919 vs 0.695
# 67/67 [==============================] - 86s 1s/step - loss: 6.5621 - accuracy: 0.0000e+00 - val_loss: 7.4833 - val_accuracy: 0.0000e+00
# Epoch 55/1000
# 4/4 [==============================] - 1s 177ms/step
# 4/4 [==============================] - 1s 150ms/step
# 4/4 [==============================] - 1s 177ms/step
# 4/4 [==============================] - 1s 160ms/step
# 3/3 [==============================] - 1s 182ms/step
# 4/4 [==============================] - 1s 155ms/step
# F-measure: 0.481 vs 0.562
# Error rate: 0.817 vs 0.695
# 67/67 [==============================] - 86s 1s/step - loss: 6.7187 - accuracy: 0.0000e+00 - val_loss: 7.6894 - val_accuracy: 0.0000e+00
# Epoch 56/1000
# 4/4 [==============================] - 1s 175ms/step
# 4/4 [==============================] - 1s 190ms/step
# 4/4 [==============================] - 1s 169ms/step
# 4/4 [==============================] - 1s 159ms/step
# 3/3 [==============================] - 1s 177ms/step
# 4/4 [==============================] - 1s 152ms/step
# F-measure: 0.354 vs 0.562
# Error rate: 1.602 vs 0.695
# 67/67 [==============================] - 83s 1s/step - loss: 6.7960 - accuracy: 0.0000e+00 - val_loss: 11.2320 - val_accuracy: 0.0165
# Epoch 57/1000
# 4/4 [==============================] - 1s 169ms/step
# 4/4 [==============================] - 1s 147ms/step
# 4/4 [==============================] - 1s 179ms/step
# 4/4 [==============================] - 1s 210ms/step
# 3/3 [==============================] - 1s 173ms/step
# 4/4 [==============================] - 1s 146ms/step
# F-measure: 0.474 vs 0.562
# Error rate: 1.049 vs 0.695
# 67/67 [==============================] - 86s 1s/step - loss: 6.5727 - accuracy: 0.0000e+00 - val_loss: 8.2789 - val_accuracy: 0.0000e+00
# Epoch 58/1000
# 4/4 [==============================] - 1s 173ms/step
# 4/4 [==============================] - 1s 151ms/step
# 4/4 [==============================] - 1s 176ms/step
# 4/4 [==============================] - 1s 162ms/step
# 3/3 [==============================] - 1s 177ms/step
# 4/4 [==============================] - 1s 152ms/step
# F-measure: 0.492 vs 0.562
# Error rate: 0.732 vs 0.695
# 67/67 [==============================] - 85s 1s/step - loss: 6.5269 - accuracy: 0.0000e+00 - val_loss: 7.0163 - val_accuracy: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-127-c8cc2565716a> in <cell line: 1>()
# ----> 1 model.fit(training_generator, validation_data=validation_generator, epochs=1000, callbacks=[KerasFinalCallback()], verbose=1)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1671             logs = None
#    1672             for epoch, iterator in data_handler.enumerate_epochs():
# -> 1673                 self.reset_metrics()
#    1674                 callbacks.on_epoch_begin(epoch)
#    1675                 with data_handler.catch_stop_iteration():
#
# KeyboardInterrupt:

# %%
loss, accuracy = model.evaluate(test_generator)#, callbacks=[KerasFinalCallback()])
print('loss:', loss)
print('accuracy:', accuracy)
# Out:
# 8/8 [==============================] - 2s 273ms/step - loss: 68.2316 - accuracy: 0.0000e+00
# loss: 68.2315673828125
# accuracy: 0.0
